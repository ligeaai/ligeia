# %%
import pandas as pd

# %%
xml = """<?xml version="1.0" encoding="utf-16"?>
<DbInfo xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema">
  <Filegroups>
    <DbFilegroup Name="PRIMARY" />
  </Filegroups>
  <Tables>
    <DbTable Name="CODE_LIST" TablespaceName="PRIMARY">
      <Columns>
        <DbColumn Name="LIST_TYPE" Precision="100" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="CULTURE" Precision="10" DefaultValueType="Culture" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="CODE" Precision="100" IsIdentity="False" IsNullable="False" LogicalDbType="Unicode" />
        <DbColumn Name="CODE_TEXT" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="PARENT" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LEGACY_CODE" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="VAL1" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL2" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL3" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL4" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL5" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL6" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL7" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL8" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL9" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL10" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="DATE1" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE2" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE3" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE4" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE5" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="CHAR1" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR2" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR3" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR4" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR5" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAYER_NAME" Precision="50" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="DESCRIPTION_ID" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="HIDDEN" Precision="5" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="LAST_UPDT_USER" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_DATE" DefaultValueType="Now" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="VERSION" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="DB_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ROW_ID" Precision="32" DefaultValueType="Guid" PkOrder="1" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="STATUS" Precision="10" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="REV_GRP_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
      </Columns>
      <Indexes>
        <DbIndex Name="AK_CODE_LIST" TablespaceName="PRIMARY" IsUnique="True">
          <ColumnNames>
            <string>LIST_TYPE</string>
            <string>CULTURE</string>
            <string>CODE</string>
            <string>PARENT</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_CODE_LIST_INC_CTEXT" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>CODE</string>
            <string>LIST_TYPE</string>
            <string>CULTURE</string>
          </ColumnNames>
          <IncludeColumnNames>
            <string>CODE_TEXT</string>
          </IncludeColumnNames>
        </DbIndex>
      </Indexes>
      <Fks />
      <Triggers />
      <PrimaryKey Name="PK_CODE_LIST" TablespaceName="PRIMARY" />
    </DbTable>
    <DbTable Name="CODE_LIST_LAYER" TablespaceName="PRIMARY">
      <Columns>
        <DbColumn Name="LIST_TYPE" Precision="100" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="CULTURE" Precision="10" DefaultValueType="Culture" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="CODE" Precision="100" IsIdentity="False" IsNullable="False" LogicalDbType="Unicode" />
        <DbColumn Name="CODE_TEXT" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="PARENT" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LEGACY_CODE" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="VAL1" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL2" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL3" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL4" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL5" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL6" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL7" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL8" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL9" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL10" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="DATE1" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE2" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE3" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE4" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE5" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="CHAR1" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR2" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR3" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR4" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR5" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAYER_NAME" Precision="50" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="DESCRIPTION_ID" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="HIDDEN" Precision="5" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="LAST_UPDT_USER" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_DATE" DefaultValueType="Now" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="VERSION" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="DB_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ROW_ID" Precision="32" DefaultValueType="Guid" PkOrder="1" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="STATUS" Precision="10" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="REV_GRP_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
      </Columns>
      <Indexes>
        <DbIndex Name="AK_CODE_LIST_LAYER" TablespaceName="PRIMARY" IsUnique="True">
          <ColumnNames>
            <string>LIST_TYPE</string>
            <string>CULTURE</string>
            <string>CODE</string>
            <string>PARENT</string>
            <string>LAYER_NAME</string>
          </ColumnNames>
        </DbIndex>
      </Indexes>
      <Fks />
      <Triggers />
      <PrimaryKey Name="PK_CODE_LIST_LAYER" TablespaceName="PRIMARY" />
    </DbTable>
    <DbTable Name="DATE_INFO" TablespaceName="PRIMARY">
      <Columns>
        <DbColumn Name="DATETIME" PkOrder="1" IsIdentity="False" IsNullable="False" LogicalDbType="Date" />
        <DbColumn Name="DATE_TYPE" Precision="1" PkOrder="2" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="NEXT_DAY_DATE" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="PREV_DAY_DATE" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="QUARTER" Scale="0" IsIdentity="False" IsNullable="True" LogicalDbType="Integer" />
        <DbColumn Name="YEAR" Scale="0" IsIdentity="False" IsNullable="True" LogicalDbType="Integer" />
        <DbColumn Name="MONTH" Scale="0" IsIdentity="False" IsNullable="True" LogicalDbType="Integer" />
        <DbColumn Name="BI_WEEK" Scale="0" IsIdentity="False" IsNullable="True" LogicalDbType="Integer" />
        <DbColumn Name="WEEK" Scale="0" IsIdentity="False" IsNullable="True" LogicalDbType="Integer" />
        <DbColumn Name="DAY" Scale="0" IsIdentity="False" IsNullable="True" LogicalDbType="Integer" />
        <DbColumn Name="DATE_YYYYMMDD" Precision="8" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="YEAR_YYYY" Precision="4" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="YEAR_YY" Precision="2" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="MONTH_MM" Precision="2" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="BI_WEEK_WW" Precision="2" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="WEEK_WW" Precision="2" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="DAY_DD" Precision="2" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="DAY_OF_WEEK" Scale="0" IsIdentity="False" IsNullable="True" LogicalDbType="Integer" />
        <DbColumn Name="BUS_DAY_OF_WEEK" Scale="0" IsIdentity="False" IsNullable="True" LogicalDbType="Integer" />
        <DbColumn Name="DAY_OF_BI_WEEK" Scale="0" IsIdentity="False" IsNullable="True" LogicalDbType="Integer" />
        <DbColumn Name="DAY_OF_MONTH" Scale="0" IsIdentity="False" IsNullable="True" LogicalDbType="Integer" />
        <DbColumn Name="DAY_OF_YEAR" Scale="0" IsIdentity="False" IsNullable="True" LogicalDbType="Integer" />
        <DbColumn Name="START_OF_YEAR_DATE" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="END_OF_YEAR_DATE" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="NEXT_YEAR_DATE" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="START_OF_WEEK_DATE" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="END_OF_WEEK_DATE" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="NEXT_WEEK_DATE" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="START_OF_MONTH_DATE" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="END_OF_MONTH_DATE" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="NEXT_MONTH_DATE" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="START_OF_BI_WEEK_DATE" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="END_OF_BI_WEEK_DATE" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="NEXT_BI_WEEK_DATE" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DAYS_IN_YEAR" Scale="0" IsIdentity="False" IsNullable="True" LogicalDbType="Integer" />
        <DbColumn Name="DAYS_IN_BI_WEEK" Scale="0" IsIdentity="False" IsNullable="True" LogicalDbType="Integer" />
        <DbColumn Name="DAYS_IN_MONTH" Scale="0" IsIdentity="False" IsNullable="True" LogicalDbType="Integer" />
        <DbColumn Name="LEAP_MONTH" Scale="0" IsIdentity="False" IsNullable="True" LogicalDbType="Integer" />
        <DbColumn Name="IS_LEAP_DAY" Precision="5" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="IS_LEAP_MONTH" Precision="5" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="IS_LEAP_YEAR" Precision="5" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
      </Columns>
      <Indexes />
      <Fks />
      <Triggers />
      <PrimaryKey Name="PK_DATE_INFO" TablespaceName="PRIMARY" />
    </DbTable>
    <DbTable Name="DB_ID" TablespaceName="PRIMARY">
      <Columns>
        <DbColumn Name="DB_ID" Precision="32" PkOrder="1" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
      </Columns>
      <Indexes />
      <Fks />
      <Triggers />
      <PrimaryKey Name="PK_DB_ID" TablespaceName="PRIMARY" />
    </DbTable>
    <DbTable Name="ITEM" TablespaceName="PRIMARY">
      <Columns>
        <DbColumn Name="ITEM_ID" Precision="32" PkOrder="1" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="ITEM_TYPE" Precision="14" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="START_DATETIME" IsIdentity="False" IsNullable="False" LogicalDbType="Date" />
        <DbColumn Name="END_DATETIME" DefaultValueType="EndDatetime" IsIdentity="False" IsNullable="False" LogicalDbType="Date" />
        <DbColumn Name="LAST_UPDT_USER" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_DATE" DefaultValueType="Now" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="VERSION" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="DB_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ROW_ID" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="STATUS" Precision="10" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="REV_GRP_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="UPDATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="CREATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
      </Columns>
      <Indexes>
        <DbIndex Name="IX_ITEM_RID" TablespaceName="PRIMARY" IsUnique="True">
          <ColumnNames>
            <string>ROW_ID</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_ITEM_TYPE_DT" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_TYPE</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
          </ColumnNames>
        </DbIndex>
      </Indexes>
      <Fks />
      <Triggers />
      <PrimaryKey Name="PK_ITEM" TablespaceName="PRIMARY" />
    </DbTable>
    <DbTable Name="ITEM_BLOB" TablespaceName="PRIMARY">
      <Columns>
        <DbColumn Name="BLOB_ID" Precision="32" PkOrder="1" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="BLOB_TYPE" Precision="14" DefaultValueType="NotAvailable" PkOrder="2" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="MIME_TYPE" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="TYPE" Precision="14" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="TYPE_PROPERTY" Precision="15" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="FILENAME" Precision="200" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="COMPRESSED_WITH" Precision="30" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="ENCRYPTED_WITH" Precision="30" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="LAST_UPDT_USER" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_DATE" DefaultValueType="Now" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="VERSION" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="DB_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ROW_ID" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="STATUS" Precision="10" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="REV_GRP_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="UPDATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="CREATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
      </Columns>
      <Indexes>
        <DbIndex Name="IX_ITEM_BLOB_RID" TablespaceName="PRIMARY" IsUnique="True">
          <ColumnNames>
            <string>ROW_ID</string>
          </ColumnNames>
        </DbIndex>
      </Indexes>
      <Fks />
      <Triggers />
      <PrimaryKey Name="PK_ITEM_BLOB" TablespaceName="PRIMARY" />
    </DbTable>
    <DbTable Name="ITEM_BLOB_STORE" TablespaceName="PRIMARY">
      <Columns>
        <DbColumn Name="BLOB_ID" Precision="32" PkOrder="1" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="BLOB_SEQ" Scale="0" PkOrder="2" IsIdentity="False" IsNullable="False" LogicalDbType="Integer" />
        <DbColumn Name="BLOB_TYPE" Precision="14" DefaultValueType="NotAvailable" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="CRC32" Precision="8" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="BLOB_DATA" IsIdentity="False" IsNullable="True" LogicalDbType="Blob" />
        <DbColumn Name="LAST_UPDT_USER" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_DATE" DefaultValueType="Now" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="VERSION" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="DB_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ROW_ID" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="STATUS" Precision="10" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="REV_GRP_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="UPDATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="CREATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
      </Columns>
      <Indexes>
        <DbIndex Name="IX_ITEM_BLOB_STORE_RID" TablespaceName="PRIMARY" IsUnique="True">
          <ColumnNames>
            <string>ROW_ID</string>
          </ColumnNames>
        </DbIndex>
      </Indexes>
      <Fks />
      <Triggers />
      <PrimaryKey Name="PK_ITEM_BLOB_STORE" TablespaceName="PRIMARY" />
    </DbTable>
    <DbTable Name="ITEM_EVENT" TablespaceName="PRIMARY">
      <Columns>
        <DbColumn Name="EVENT_GROUP_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ITEM_ID" Precision="32" PkOrder="2" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="EVENT_TYPE" Precision="14" PkOrder="1" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="PERIOD" Precision="20" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="START_DATETIME" PkOrder="3" IsIdentity="False" IsNullable="False" LogicalDbType="Date" />
        <DbColumn Name="END_DATETIME" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="VAL1" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL2" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL3" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL4" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL5" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL6" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL7" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL8" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL9" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL10" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL11" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL12" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL13" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL14" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL15" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL16" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL17" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL18" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL19" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL20" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL21" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL22" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL23" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL24" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL25" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL26" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL27" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL28" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL29" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL30" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL31" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL32" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL33" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL34" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL35" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL36" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL37" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL38" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL39" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL40" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL41" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL42" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL43" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL44" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL45" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL46" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL47" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL48" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL49" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL50" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL51" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL52" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL53" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL54" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL55" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL56" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL57" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL58" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL59" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL60" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL61" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL62" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL63" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL64" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL65" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL66" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL67" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL68" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL69" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL70" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL71" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL72" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL73" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL74" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL75" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="DATE1" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE2" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE3" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE4" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE5" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="CHAR1" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR2" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR3" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR4" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR5" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR6" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR7" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR8" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR9" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR10" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR11" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR12" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR13" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR14" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR15" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_USER" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_DATE" DefaultValueType="Now" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="VERSION" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="DB_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ROW_ID" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="STATUS" Precision="10" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="REV_GRP_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="UPDATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="CREATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
      </Columns>
      <Indexes>
        <DbIndex Name="IX_ITEM_EVENT" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>EVENT_GROUP_ID</string>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
            <string>PERIOD</string>
            <string>START_DATETIME</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT2" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT3" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_TYPE" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>EVENT_TYPE</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_RID" TablespaceName="PRIMARY" IsUnique="True">
          <ColumnNames>
            <string>ROW_ID</string>
          </ColumnNames>
        </DbIndex>
      </Indexes>
      <Fks />
      <Triggers />
      <PrimaryKey Name="PK_ITEM_EVENT" TablespaceName="PRIMARY" />
    </DbTable>
    <DbTable Name="ITEM_EVENT_SC" TablespaceName="PRIMARY">
      <Columns>
        <DbColumn Name="EVENT_GROUP_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="SCENARIO_ID" Precision="32" PkOrder="1" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="ITEM_ID" Precision="32" PkOrder="3" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="EVENT_TYPE" Precision="14" PkOrder="2" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="PERIOD" Precision="20" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="START_DATETIME" PkOrder="4" IsIdentity="False" IsNullable="False" LogicalDbType="Date" />
        <DbColumn Name="END_DATETIME" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="VAL1" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL2" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL3" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL4" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL5" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL6" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL7" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL8" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL9" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL10" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL11" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL12" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL13" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL14" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL15" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL16" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL17" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL18" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL19" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL20" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL21" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL22" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL23" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL24" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL25" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL26" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL27" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL28" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL29" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL30" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL31" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL32" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL33" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL34" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL35" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL36" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL37" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL38" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL39" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL40" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL41" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL42" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL43" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL44" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL45" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL46" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL47" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL48" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL49" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL50" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL51" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL52" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL53" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL54" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL55" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL56" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL57" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL58" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL59" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL60" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL61" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL62" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL63" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL64" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL65" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL66" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL67" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL68" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL69" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL70" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL71" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL72" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL73" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL74" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL75" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="DATE1" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE2" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE3" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE4" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE5" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="CHAR1" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR2" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR3" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR4" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR5" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR6" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR7" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR8" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR9" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR10" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR11" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR12" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR13" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR14" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR15" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_USER" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_DATE" DefaultValueType="Now" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="VERSION" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="DB_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ROW_ID" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="STATUS" Precision="10" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="REV_GRP_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="UPDATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="CREATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
      </Columns>
      <Indexes>
        <DbIndex Name="IX_ITEM_EVENT_SC" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>EVENT_GROUP_ID</string>
            <string>SCENARIO_ID</string>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
            <string>PERIOD</string>
            <string>START_DATETIME</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT2_SC" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>SCENARIO_ID</string>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT3_SC" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>SCENARIO_ID</string>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_TYPE_SC" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>SCENARIO_ID</string>
            <string>EVENT_TYPE</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_SC_RID" TablespaceName="PRIMARY" IsUnique="True">
          <ColumnNames>
            <string>ROW_ID</string>
          </ColumnNames>
        </DbIndex>
      </Indexes>
      <Fks />
      <Triggers />
      <PrimaryKey Name="PK_ITEM_EVENT_SC" TablespaceName="PRIMARY" />
    </DbTable>
    <DbTable Name="ITEM_EVENT_DBL_EXT" TablespaceName="PRIMARY">
      <Columns>
        <DbColumn Name="EVENT_GROUP_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ITEM_ID" Precision="32" PkOrder="1" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="EVENT_TYPE" Precision="14" PkOrder="2" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="PERIOD" Precision="20" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="START_DATETIME" PkOrder="5" IsIdentity="False" IsNullable="False" LogicalDbType="Date" />
        <DbColumn Name="END_DATETIME" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="KEY_EXT1" Precision="50" PkOrder="3" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="KEY_EXT2" Precision="50" PkOrder="4" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="ITEM_REF1" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ITEM_REF2" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ITEM_REF3" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ITEM_REF4" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ITEM_REF5" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="VAL1" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL2" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL3" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL4" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL5" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL6" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL7" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL8" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL9" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL10" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL11" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL12" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL13" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL14" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL15" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL16" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL17" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL18" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL19" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL20" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL21" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL22" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL23" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL24" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL25" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL26" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL27" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL28" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL29" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL30" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL31" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL32" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL33" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL34" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL35" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL36" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL37" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL38" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL39" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL40" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL41" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL42" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL43" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL44" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL45" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL46" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL47" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL48" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL49" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL50" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="DATE1" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE2" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE3" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE4" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE5" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="CHAR1" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR2" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR3" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR4" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR5" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR6" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR7" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR8" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR9" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR10" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_USER" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_DATE" DefaultValueType="Now" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="VERSION" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="DB_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ROW_ID" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="STATUS" Precision="10" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="REV_GRP_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="UPDATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="CREATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
      </Columns>
      <Indexes>
        <DbIndex Name="IX_ITEM_EVENT_DBL_EXT" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>EVENT_GROUP_ID</string>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
            <string>PERIOD</string>
            <string>START_DATETIME</string>
            <string>KEY_EXT1</string>
            <string>KEY_EXT2</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_DBL_EXT2" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_DBL_EXT3" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_DBL_EXT_REF1" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_REF1</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_DBL_EXT_REF2" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_REF2</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_DBL_EXT_REF3" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_REF3</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_DBL_EXT_REF4" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_REF4</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_DBL_EXT_REF5" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_REF5</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_DBL_EXT_TYPE" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>EVENT_TYPE</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_DBL_EXT_RID" TablespaceName="PRIMARY" IsUnique="True">
          <ColumnNames>
            <string>ROW_ID</string>
          </ColumnNames>
        </DbIndex>
      </Indexes>
      <Fks>
        <DbFk Name="FK_ITEM_EVENT_DBL_EXT_ITEM1" RefTableName="ITEM" UpdateRule="None" DeleteRule="None">
          <FkColumnNames>
            <string>ITEM_REF1</string>
          </FkColumnNames>
          <RefColumnNames>
            <string>ITEM_ID</string>
          </RefColumnNames>
        </DbFk>
        <DbFk Name="FK_ITEM_EVENT_DBL_EXT_ITEM2" RefTableName="ITEM" UpdateRule="None" DeleteRule="None">
          <FkColumnNames>
            <string>ITEM_REF2</string>
          </FkColumnNames>
          <RefColumnNames>
            <string>ITEM_ID</string>
          </RefColumnNames>
        </DbFk>
        <DbFk Name="FK_ITEM_EVENT_DBL_EXT_ITEM3" RefTableName="ITEM" UpdateRule="None" DeleteRule="None">
          <FkColumnNames>
            <string>ITEM_REF3</string>
          </FkColumnNames>
          <RefColumnNames>
            <string>ITEM_ID</string>
          </RefColumnNames>
        </DbFk>
        <DbFk Name="FK_ITEM_EVENT_DBL_EXT_ITEM4" RefTableName="ITEM" UpdateRule="None" DeleteRule="None">
          <FkColumnNames>
            <string>ITEM_REF4</string>
          </FkColumnNames>
          <RefColumnNames>
            <string>ITEM_ID</string>
          </RefColumnNames>
        </DbFk>
        <DbFk Name="FK_ITEM_EVENT_DBL_EXT_ITEM5" RefTableName="ITEM" UpdateRule="None" DeleteRule="None">
          <FkColumnNames>
            <string>ITEM_REF5</string>
          </FkColumnNames>
          <RefColumnNames>
            <string>ITEM_ID</string>
          </RefColumnNames>
        </DbFk>
      </Fks>
      <Triggers />
      <PrimaryKey Name="PK_ITEM_EVENT_DBL_EXT" TablespaceName="PRIMARY" />
    </DbTable>
    <DbTable Name="ITEM_EVENT_SC_DBL" TablespaceName="PRIMARY">
      <Columns>
        <DbColumn Name="EVENT_GROUP_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="SCENARIO_ID" Precision="32" PkOrder="1" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="ITEM_ID" Precision="32" PkOrder="2" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="EVENT_TYPE" Precision="14" PkOrder="3" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="PERIOD" Precision="20" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="START_DATETIME" PkOrder="6" IsIdentity="False" IsNullable="False" LogicalDbType="Date" />
        <DbColumn Name="END_DATETIME" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="KEY_EXT1" Precision="50" PkOrder="4" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="KEY_EXT2" Precision="50" PkOrder="5" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="ITEM_REF1" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ITEM_REF2" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ITEM_REF3" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ITEM_REF4" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ITEM_REF5" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="VAL1" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL2" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL3" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL4" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL5" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL6" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL7" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL8" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL9" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL10" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL11" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL12" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL13" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL14" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL15" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL16" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL17" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL18" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL19" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL20" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL21" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL22" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL23" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL24" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL25" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL26" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL27" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL28" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL29" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL30" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL31" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL32" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL33" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL34" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL35" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL36" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL37" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL38" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL39" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL40" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL41" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL42" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL43" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL44" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL45" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL46" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL47" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL48" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL49" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL50" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="DATE1" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE2" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE3" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE4" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE5" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="CHAR1" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR2" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR3" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR4" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR5" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR6" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR7" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR8" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR9" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR10" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_USER" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_DATE" DefaultValueType="Now" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="VERSION" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="DB_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ROW_ID" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="STATUS" Precision="10" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="REV_GRP_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="UPDATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="CREATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
      </Columns>
      <Indexes>
        <DbIndex Name="IX_ITEM_EVENT_SC_DBL" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>EVENT_GROUP_ID</string>
            <string>SCENARIO_ID</string>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
            <string>PERIOD</string>
            <string>START_DATETIME</string>
            <string>KEY_EXT1</string>
            <string>KEY_EXT2</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_SC_DBL2" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>SCENARIO_ID</string>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_SC_DBL3" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>SCENARIO_ID</string>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_SC_DBL_REF1" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_REF1</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_SC_DBL_REF2" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_REF2</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_SC_DBL_REF3" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_REF3</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_SC_DBL_REF4" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_REF4</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_SC_DBL_REF5" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_REF5</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_SC_DBL_TYPE" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>EVENT_TYPE</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_SC_DBL_RID" TablespaceName="PRIMARY" IsUnique="True">
          <ColumnNames>
            <string>ROW_ID</string>
          </ColumnNames>
        </DbIndex>
      </Indexes>
      <Fks>
        <DbFk Name="FK_ITEM_EVENT_SC_DBL_ITEM1" RefTableName="ITEM" UpdateRule="None" DeleteRule="None">
          <FkColumnNames>
            <string>ITEM_REF1</string>
          </FkColumnNames>
          <RefColumnNames>
            <string>ITEM_ID</string>
          </RefColumnNames>
        </DbFk>
        <DbFk Name="FK_ITEM_EVENT_SC_DBL_ITEM2" RefTableName="ITEM" UpdateRule="None" DeleteRule="None">
          <FkColumnNames>
            <string>ITEM_REF2</string>
          </FkColumnNames>
          <RefColumnNames>
            <string>ITEM_ID</string>
          </RefColumnNames>
        </DbFk>
        <DbFk Name="FK_ITEM_EVENT_SC_DBL_ITEM3" RefTableName="ITEM" UpdateRule="None" DeleteRule="None">
          <FkColumnNames>
            <string>ITEM_REF3</string>
          </FkColumnNames>
          <RefColumnNames>
            <string>ITEM_ID</string>
          </RefColumnNames>
        </DbFk>
        <DbFk Name="FK_ITEM_EVENT_SC_DBL_ITEM4" RefTableName="ITEM" UpdateRule="None" DeleteRule="None">
          <FkColumnNames>
            <string>ITEM_REF4</string>
          </FkColumnNames>
          <RefColumnNames>
            <string>ITEM_ID</string>
          </RefColumnNames>
        </DbFk>
        <DbFk Name="FK_ITEM_EVENT_SC_DBL_ITEM5" RefTableName="ITEM" UpdateRule="None" DeleteRule="None">
          <FkColumnNames>
            <string>ITEM_REF5</string>
          </FkColumnNames>
          <RefColumnNames>
            <string>ITEM_ID</string>
          </RefColumnNames>
        </DbFk>
      </Fks>
      <Triggers />
      <PrimaryKey Name="PK_ITEM_EVENT_SC_DBL" TablespaceName="PRIMARY" />
    </DbTable>
    <DbTable Name="ITEM_EVENT_DBL_DATE" TablespaceName="PRIMARY">
      <Columns>
        <DbColumn Name="EVENT_GROUP_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ITEM_ID" Precision="32" PkOrder="1" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="EVENT_TYPE" Precision="14" PkOrder="2" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="PERIOD" Precision="20" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="START_DATETIME" PkOrder="5" IsIdentity="False" IsNullable="False" LogicalDbType="Date" />
        <DbColumn Name="END_DATETIME" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="KEY_EXT1" PkOrder="3" IsIdentity="False" IsNullable="False" LogicalDbType="Date" />
        <DbColumn Name="KEY_EXT2" PkOrder="4" IsIdentity="False" IsNullable="False" LogicalDbType="Date" />
        <DbColumn Name="ITEM_REF1" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ITEM_REF2" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ITEM_REF3" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ITEM_REF4" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ITEM_REF5" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="VAL1" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL2" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL3" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL4" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL5" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL6" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL7" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL8" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL9" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL10" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL11" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL12" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL13" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL14" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL15" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL16" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL17" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL18" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL19" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL20" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL21" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL22" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL23" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL24" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL25" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL26" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL27" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL28" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL29" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL30" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL31" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL32" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL33" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL34" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL35" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL36" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL37" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL38" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL39" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL40" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL41" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL42" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL43" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL44" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL45" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL46" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL47" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL48" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL49" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL50" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="DATE1" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE2" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE3" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE4" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE5" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="CHAR1" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR2" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR3" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR4" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR5" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR6" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR7" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR8" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR9" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR10" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_USER" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_DATE" DefaultValueType="Now" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="VERSION" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="DB_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ROW_ID" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="STATUS" Precision="10" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="REV_GRP_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="UPDATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="CREATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
      </Columns>
      <Indexes>
        <DbIndex Name="IX_ITEM_EVENT_DBL_DATE" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>EVENT_GROUP_ID</string>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
            <string>PERIOD</string>
            <string>START_DATETIME</string>
            <string>KEY_EXT1</string>
            <string>KEY_EXT2</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_DBL_DATE2" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_DBL_DATE3" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_DBL_DATE_REF1" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_REF1</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_DBL_DATE_REF2" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_REF2</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_DBL_DATE_REF3" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_REF3</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_DBL_DATE_REF4" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_REF4</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_DBL_DATE_REF5" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_REF5</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_DBL_DATE_TYPE" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>EVENT_TYPE</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_DBL_DATE_RID" TablespaceName="PRIMARY" IsUnique="True">
          <ColumnNames>
            <string>ROW_ID</string>
          </ColumnNames>
        </DbIndex>
      </Indexes>
      <Fks>
        <DbFk Name="FK_ITEM_EVENT_DBL_DATE_ITEM1" RefTableName="ITEM" UpdateRule="None" DeleteRule="None">
          <FkColumnNames>
            <string>ITEM_REF1</string>
          </FkColumnNames>
          <RefColumnNames>
            <string>ITEM_ID</string>
          </RefColumnNames>
        </DbFk>
        <DbFk Name="FK_ITEM_EVENT_DBL_DATET_ITEM2" RefTableName="ITEM" UpdateRule="None" DeleteRule="None">
          <FkColumnNames>
            <string>ITEM_REF2</string>
          </FkColumnNames>
          <RefColumnNames>
            <string>ITEM_ID</string>
          </RefColumnNames>
        </DbFk>
        <DbFk Name="FK_ITEM_EVENT_DBL_DATE_ITEM3" RefTableName="ITEM" UpdateRule="None" DeleteRule="None">
          <FkColumnNames>
            <string>ITEM_REF3</string>
          </FkColumnNames>
          <RefColumnNames>
            <string>ITEM_ID</string>
          </RefColumnNames>
        </DbFk>
        <DbFk Name="FK_ITEM_EVENT_DBL_DATE_ITEM4" RefTableName="ITEM" UpdateRule="None" DeleteRule="None">
          <FkColumnNames>
            <string>ITEM_REF4</string>
          </FkColumnNames>
          <RefColumnNames>
            <string>ITEM_ID</string>
          </RefColumnNames>
        </DbFk>
        <DbFk Name="FK_ITEM_EVENT_DBL_DATE_ITEM5" RefTableName="ITEM" UpdateRule="None" DeleteRule="None">
          <FkColumnNames>
            <string>ITEM_REF5</string>
          </FkColumnNames>
          <RefColumnNames>
            <string>ITEM_ID</string>
          </RefColumnNames>
        </DbFk>
      </Fks>
      <Triggers />
      <PrimaryKey Name="PK_ITEM_EVENT_DBL_DATE" TablespaceName="PRIMARY" />
    </DbTable>
    <DbTable Name="ITEM_EVENT_EXT" TablespaceName="PRIMARY">
      <Columns>
        <DbColumn Name="EVENT_GROUP_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ITEM_ID" Precision="32" PkOrder="1" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="EVENT_TYPE" Precision="14" PkOrder="2" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="PERIOD" Precision="20" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="START_DATETIME" PkOrder="4" IsIdentity="False" IsNullable="False" LogicalDbType="Date" />
        <DbColumn Name="END_DATETIME" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="KEY_EXT" Precision="50" PkOrder="3" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="ITEM_REF1" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ITEM_REF2" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ITEM_REF3" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ITEM_REF4" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ITEM_REF5" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ITEM_REF6" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ITEM_REF7" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ITEM_REF8" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ITEM_REF9" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="VAL1" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL2" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL3" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL4" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL5" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL6" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL7" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL8" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL9" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL10" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL11" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL12" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL13" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL14" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL15" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL16" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL17" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL18" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL19" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL20" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL21" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL22" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL23" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL24" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL25" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL26" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL27" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL28" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL29" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL30" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL31" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL32" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL33" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL34" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL35" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL36" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL37" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL38" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL39" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL40" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL41" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL42" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL43" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL44" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL45" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL46" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL47" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL48" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL49" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL50" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL51" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL52" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL53" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL54" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL55" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL56" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL57" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL58" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL59" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL60" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL61" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL62" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL63" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL64" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL65" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL66" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL67" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL68" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL69" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL70" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL71" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL72" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL73" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL74" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL75" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL76" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL77" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL78" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL79" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL80" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL81" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL82" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL83" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL84" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL85" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL86" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL87" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL88" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL89" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL90" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="DATE1" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE2" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE3" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE4" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE5" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="CHAR1" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR2" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR3" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR4" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR5" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR6" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR7" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR8" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR9" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR10" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR11" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR12" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR13" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR14" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR15" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR16" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR17" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR18" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR19" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR20" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_USER" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_DATE" DefaultValueType="Now" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="VERSION" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="DB_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ROW_ID" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="STATUS" Precision="10" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="REV_GRP_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="UPDATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="CREATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
      </Columns>
      <Indexes>
        <DbIndex Name="IX_ITEM_EVENT_EXT" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>EVENT_GROUP_ID</string>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
            <string>PERIOD</string>
            <string>START_DATETIME</string>
            <string>KEY_EXT</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_EXT2" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_EXT3" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_EXT_REF1" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_REF1</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_EXT_REF2" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_REF2</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_EXT_REF3" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_REF3</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_EXT_REF4" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_REF4</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_EXT_REF5" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_REF5</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_EXT_TYPE" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>EVENT_TYPE</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_EXT_RID" TablespaceName="PRIMARY" IsUnique="True">
          <ColumnNames>
            <string>ROW_ID</string>
          </ColumnNames>
        </DbIndex>
      </Indexes>
      <Fks>
        <DbFk Name="FK_ITEM_EVENT_EXT_ITEM1" RefTableName="ITEM" UpdateRule="None" DeleteRule="None">
          <FkColumnNames>
            <string>ITEM_REF1</string>
          </FkColumnNames>
          <RefColumnNames>
            <string>ITEM_ID</string>
          </RefColumnNames>
        </DbFk>
        <DbFk Name="FK_ITEM_EVENT_EXT_ITEM2" RefTableName="ITEM" UpdateRule="None" DeleteRule="None">
          <FkColumnNames>
            <string>ITEM_REF2</string>
          </FkColumnNames>
          <RefColumnNames>
            <string>ITEM_ID</string>
          </RefColumnNames>
        </DbFk>
        <DbFk Name="FK_ITEM_EVENT_EXT_ITEM3" RefTableName="ITEM" UpdateRule="None" DeleteRule="None">
          <FkColumnNames>
            <string>ITEM_REF3</string>
          </FkColumnNames>
          <RefColumnNames>
            <string>ITEM_ID</string>
          </RefColumnNames>
        </DbFk>
        <DbFk Name="FK_ITEM_EVENT_EXT_ITEM4" RefTableName="ITEM" UpdateRule="None" DeleteRule="None">
          <FkColumnNames>
            <string>ITEM_REF4</string>
          </FkColumnNames>
          <RefColumnNames>
            <string>ITEM_ID</string>
          </RefColumnNames>
        </DbFk>
        <DbFk Name="FK_ITEM_EVENT_EXT_ITEM5" RefTableName="ITEM" UpdateRule="None" DeleteRule="None">
          <FkColumnNames>
            <string>ITEM_REF5</string>
          </FkColumnNames>
          <RefColumnNames>
            <string>ITEM_ID</string>
          </RefColumnNames>
        </DbFk>
      </Fks>
      <Triggers />
      <PrimaryKey Name="PK_ITEM_EVENT_EXT" TablespaceName="PRIMARY" />
    </DbTable>
    <DbTable Name="ITEM_EVENT_SC_EXT" TablespaceName="PRIMARY">
      <Columns>
        <DbColumn Name="EVENT_GROUP_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="SCENARIO_ID" Precision="32" PkOrder="1" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="ITEM_ID" Precision="32" PkOrder="2" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="EVENT_TYPE" Precision="14" PkOrder="3" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="PERIOD" Precision="20" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="START_DATETIME" PkOrder="4" IsIdentity="False" IsNullable="False" LogicalDbType="Date" />
        <DbColumn Name="END_DATETIME" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="KEY_EXT" Precision="50" PkOrder="4" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="ITEM_REF1" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ITEM_REF2" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ITEM_REF3" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ITEM_REF4" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ITEM_REF5" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="VAL1" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL2" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL3" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL4" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL5" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL6" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL7" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL8" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL9" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL10" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL11" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL12" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL13" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL14" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL15" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL16" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL17" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL18" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL19" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL20" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL21" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL22" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL23" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL24" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL25" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL26" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL27" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL28" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL29" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL30" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL31" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL32" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL33" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL34" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL35" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL36" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL37" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL38" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL39" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL40" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL41" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL42" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL43" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL44" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL45" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL46" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL47" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL48" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL49" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL50" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL51" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL52" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL53" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL54" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL55" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL56" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL57" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL58" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL59" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL60" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL61" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL62" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL63" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL64" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL65" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL66" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL67" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL68" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL69" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL70" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL71" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL72" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL73" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL74" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL75" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="DATE1" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE2" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE3" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE4" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE5" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="CHAR1" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR2" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR3" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR4" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR5" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR6" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR7" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR8" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR9" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR10" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR11" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR12" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR13" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR14" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR15" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR16" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR17" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR18" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR19" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR20" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_USER" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_DATE" DefaultValueType="Now" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="VERSION" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="DB_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ROW_ID" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="STATUS" Precision="10" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="REV_GRP_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="UPDATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="CREATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
      </Columns>
      <Indexes>
        <DbIndex Name="IX_ITEM_EVENT_SC_EXT" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>EVENT_GROUP_ID</string>
            <string>SCENARIO_ID</string>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
            <string>PERIOD</string>
            <string>START_DATETIME</string>
            <string>KEY_EXT</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_SC_EXT2" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>SCENARIO_ID</string>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_SC_EXT3" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>SCENARIO_ID</string>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_SC_EXT_REF1" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_REF1</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_SC_EXT_REF2" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_REF2</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_SC_EXT_REF3" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_REF3</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_SC_EXT_REF4" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_REF4</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_SC_EXT_REF5" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_REF5</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_SC_EXT_TYPE" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>EVENT_TYPE</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_SC_EXT_RID" TablespaceName="PRIMARY" IsUnique="True">
          <ColumnNames>
            <string>ROW_ID</string>
          </ColumnNames>
        </DbIndex>
      </Indexes>
      <Fks>
        <DbFk Name="FK_ITEM_EVENT_SC_EXT_ITEM1" RefTableName="ITEM" UpdateRule="None" DeleteRule="None">
          <FkColumnNames>
            <string>ITEM_REF1</string>
          </FkColumnNames>
          <RefColumnNames>
            <string>ITEM_ID</string>
          </RefColumnNames>
        </DbFk>
        <DbFk Name="FK_ITEM_EVENT_SC_EXT_ITEM2" RefTableName="ITEM" UpdateRule="None" DeleteRule="None">
          <FkColumnNames>
            <string>ITEM_REF2</string>
          </FkColumnNames>
          <RefColumnNames>
            <string>ITEM_ID</string>
          </RefColumnNames>
        </DbFk>
        <DbFk Name="FK_ITEM_EVENT_SC_EXT_ITEM3" RefTableName="ITEM" UpdateRule="None" DeleteRule="None">
          <FkColumnNames>
            <string>ITEM_REF3</string>
          </FkColumnNames>
          <RefColumnNames>
            <string>ITEM_ID</string>
          </RefColumnNames>
        </DbFk>
        <DbFk Name="FK_ITEM_EVENT_SC_EXT_ITEM4" RefTableName="ITEM" UpdateRule="None" DeleteRule="None">
          <FkColumnNames>
            <string>ITEM_REF4</string>
          </FkColumnNames>
          <RefColumnNames>
            <string>ITEM_ID</string>
          </RefColumnNames>
        </DbFk>
        <DbFk Name="FK_ITEM_EVENT_SC_EXT_ITEM5" RefTableName="ITEM" UpdateRule="None" DeleteRule="None">
          <FkColumnNames>
            <string>ITEM_REF5</string>
          </FkColumnNames>
          <RefColumnNames>
            <string>ITEM_ID</string>
          </RefColumnNames>
        </DbFk>
      </Fks>
      <Triggers />
      <PrimaryKey Name="PK_ITEM_EVENT_SC_EXT" TablespaceName="PRIMARY" />
    </DbTable>
    <DbTable Name="ITEM_EVENT_LINK" TablespaceName="PRIMARY">
      <Columns>
        <DbColumn Name="LINK_TYPE" Precision="14" PkOrder="1" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="FROM_ROW_ID" Precision="32" PkOrder="2" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="FROM_ITEM_TYPE" Precision="14" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="TO_ROW_ID" Precision="32" PkOrder="3" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="TO_ITEM_TYPE" Precision="14" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="COLL_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="FROM_VERSION" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="TO_VERSION" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="LAST_UPDT_USER" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_DATE" DefaultValueType="Now" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="VERSION" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="DB_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ROW_ID" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="STATUS" Precision="10" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="REV_GRP_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="UPDATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="CREATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
      </Columns>
      <Indexes>
        <DbIndex Name="IX_ITEM_EVENT_LINK1" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>LINK_TYPE</string>
            <string>TO_ITEM_TYPE</string>
            <string>TO_ROW_ID</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_LINK2" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>LINK_TYPE</string>
            <string>FROM_ITEM_TYPE</string>
            <string>FROM_ROW_ID</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_LINK3" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>LINK_TYPE</string>
            <string>COLL_ID</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_LINK4" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>LINK_TYPE</string>
            <string>TO_ROW_ID</string>
            <string>FROM_ROW_ID</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_LINK_RID" TablespaceName="PRIMARY" IsUnique="True">
          <ColumnNames>
            <string>ROW_ID</string>
          </ColumnNames>
        </DbIndex>
      </Indexes>
      <Fks />
      <Triggers />
      <PrimaryKey Name="PK_ITEM_EVENT_LINK" TablespaceName="PRIMARY" />
    </DbTable>
    <DbTable Name="ITEM_EVENT_PENT_EXT" TablespaceName="PRIMARY">
      <Columns>
        <DbColumn Name="EVENT_GROUP_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ITEM_ID" Precision="32" PkOrder="1" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="EVENT_TYPE" Precision="14" PkOrder="2" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="PERIOD" Precision="20" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="START_DATETIME" PkOrder="7" IsIdentity="False" IsNullable="False" LogicalDbType="Date" />
        <DbColumn Name="END_DATETIME" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="KEY_EXT1" Precision="50" PkOrder="3" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="KEY_EXT2" Precision="50" PkOrder="4" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="KEY_EXT3" Precision="50" PkOrder="5" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="KEY_EXT4" Precision="50" PkOrder="6" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="KEY_EXT5" Precision="50" PkOrder="7" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="ITEM_REF1" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ITEM_REF2" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ITEM_REF3" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="VAL1" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL2" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL3" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL4" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL5" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL6" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL7" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL8" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL9" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL10" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL11" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL12" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL13" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL14" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL15" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL16" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL17" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL18" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL19" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL20" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="DATE1" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE2" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE3" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="CHAR1" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR2" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR3" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR4" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR5" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_USER" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_DATE" DefaultValueType="Now" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="VERSION" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="DB_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ROW_ID" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="STATUS" Precision="10" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="REV_GRP_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="UPDATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="CREATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
      </Columns>
      <Indexes>
        <DbIndex Name="IX_ITEM_EVENT_PENT_EXT" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>EVENT_GROUP_ID</string>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
            <string>PERIOD</string>
            <string>START_DATETIME</string>
            <string>KEY_EXT1</string>
            <string>KEY_EXT2</string>
            <string>KEY_EXT3</string>
            <string>KEY_EXT4</string>
            <string>KEY_EXT5</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_PENT_EXT2" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_PENT_EXT3" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_PENT_EXT_REF1" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_REF1</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_PENT_EXT_REF2" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_REF2</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_PENT_EXT_REF3" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_REF3</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_PENT_EXT_TYPE" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>EVENT_TYPE</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_PENT_EXT_RID" TablespaceName="PRIMARY" IsUnique="True">
          <ColumnNames>
            <string>ROW_ID</string>
          </ColumnNames>
        </DbIndex>
      </Indexes>
      <Fks>
        <DbFk Name="FK_ITEM_EVENT_PENT_EXT_ITEM1" RefTableName="ITEM" UpdateRule="None" DeleteRule="None">
          <FkColumnNames>
            <string>ITEM_REF1</string>
          </FkColumnNames>
          <RefColumnNames>
            <string>ITEM_ID</string>
          </RefColumnNames>
        </DbFk>
        <DbFk Name="FK_ITEM_EVENT_PENT_EXT_ITEM2" RefTableName="ITEM" UpdateRule="None" DeleteRule="None">
          <FkColumnNames>
            <string>ITEM_REF2</string>
          </FkColumnNames>
          <RefColumnNames>
            <string>ITEM_ID</string>
          </RefColumnNames>
        </DbFk>
        <DbFk Name="FK_ITEM_EVENT_PENT_EXT_ITEM3" RefTableName="ITEM" UpdateRule="None" DeleteRule="None">
          <FkColumnNames>
            <string>ITEM_REF3</string>
          </FkColumnNames>
          <RefColumnNames>
            <string>ITEM_ID</string>
          </RefColumnNames>
        </DbFk>
      </Fks>
      <Triggers />
      <PrimaryKey Name="PK_ITEM_EVENT_PENT_EXT" TablespaceName="PRIMARY" />
    </DbTable>
    <DbTable Name="ITEM_EVENT_QUAD_EXT" TablespaceName="PRIMARY">
      <Columns>
        <DbColumn Name="EVENT_GROUP_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ITEM_ID" Precision="32" PkOrder="1" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="EVENT_TYPE" Precision="14" PkOrder="2" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="PERIOD" Precision="20" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="START_DATETIME" PkOrder="7" IsIdentity="False" IsNullable="False" LogicalDbType="Date" />
        <DbColumn Name="END_DATETIME" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="KEY_EXT1" Precision="50" PkOrder="3" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="KEY_EXT2" Precision="50" PkOrder="4" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="KEY_EXT3" Precision="50" PkOrder="5" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="KEY_EXT4" Precision="50" PkOrder="6" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="ITEM_REF1" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ITEM_REF2" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ITEM_REF3" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="VAL1" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL2" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL3" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL4" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL5" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL6" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL7" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL8" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL9" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL10" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL11" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL12" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL13" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL14" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL15" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL16" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL17" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL18" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL19" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL20" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="DATE1" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE2" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE3" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="CHAR1" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR2" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR3" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR4" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR5" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_USER" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_DATE" DefaultValueType="Now" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="VERSION" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="DB_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ROW_ID" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="STATUS" Precision="10" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="REV_GRP_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="UPDATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="CREATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
      </Columns>
      <Indexes>
        <DbIndex Name="IX_ITEM_EVENT_QUAD_EXT" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>EVENT_GROUP_ID</string>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
            <string>PERIOD</string>
            <string>START_DATETIME</string>
            <string>KEY_EXT1</string>
            <string>KEY_EXT2</string>
            <string>KEY_EXT3</string>
            <string>KEY_EXT4</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_QUAD_EXT2" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_QUAD_EXT3" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_QUAD_EXT_REF1" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_REF1</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_QUAD_EXT_REF2" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_REF2</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_QUAD_EXT_REF3" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_REF3</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_QUAD_EXT_TYPE" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>EVENT_TYPE</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_QUAD_EXT_RID" TablespaceName="PRIMARY" IsUnique="True">
          <ColumnNames>
            <string>ROW_ID</string>
          </ColumnNames>
        </DbIndex>
      </Indexes>
      <Fks>
        <DbFk Name="FK_ITEM_EVENT_QUAD_EXT_ITEM1" RefTableName="ITEM" UpdateRule="None" DeleteRule="None">
          <FkColumnNames>
            <string>ITEM_REF1</string>
          </FkColumnNames>
          <RefColumnNames>
            <string>ITEM_ID</string>
          </RefColumnNames>
        </DbFk>
        <DbFk Name="FK_ITEM_EVENT_QUAD_EXT_ITEM2" RefTableName="ITEM" UpdateRule="None" DeleteRule="None">
          <FkColumnNames>
            <string>ITEM_REF2</string>
          </FkColumnNames>
          <RefColumnNames>
            <string>ITEM_ID</string>
          </RefColumnNames>
        </DbFk>
        <DbFk Name="FK_ITEM_EVENT_QUAD_EXT_ITEM3" RefTableName="ITEM" UpdateRule="None" DeleteRule="None">
          <FkColumnNames>
            <string>ITEM_REF3</string>
          </FkColumnNames>
          <RefColumnNames>
            <string>ITEM_ID</string>
          </RefColumnNames>
        </DbFk>
      </Fks>
      <Triggers />
      <PrimaryKey Name="PK_ITEM_EVENT_QUAD_EXT" TablespaceName="PRIMARY" />
    </DbTable>
    <DbTable Name="ITEM_EVENT_TAG" TablespaceName="PRIMARY">
      <Columns>
        <DbColumn Name="EVENT_GROUP_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ITEM_ID" Precision="32" PkOrder="1" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="EVENT_TYPE" Precision="14" PkOrder="2" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="PERIOD" Precision="20" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="START_DATETIME" PkOrder="4" IsIdentity="False" IsNullable="False" LogicalDbType="Date" />
        <DbColumn Name="END_DATETIME" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="PROPERTY_NAME" Precision="50" PkOrder="3" IsIdentity="False" IsNullable="False" LogicalDbType="Unicode" />
        <DbColumn Name="VAL1" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL1_DC" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="DATE1" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE1_DC" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="CHAR1" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR1_DC" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="IS_VALID" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_USER" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_DATE" DefaultValueType="Now" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="VERSION" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="DB_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ROW_ID" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="STATUS" Precision="10" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="REV_GRP_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="UPDATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="CREATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
      </Columns>
      <Indexes>
        <DbIndex Name="IX_ITEM_EVENT_TAG_RID" TablespaceName="PRIMARY" IsUnique="True">
          <ColumnNames>
            <string>ROW_ID</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_TAG_TYPE" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>EVENT_TYPE</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_TAG2" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_TAG3" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_TAG" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>EVENT_GROUP_ID</string>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
            <string>PERIOD</string>
            <string>START_DATETIME</string>
            <string>PROPERTY_NAME</string>
          </ColumnNames>
        </DbIndex>
      </Indexes>
      <Fks />
      <Triggers />
      <PrimaryKey Name="PK_ITEM_EVENT_TAG" TablespaceName="PRIMARY" />
    </DbTable>
    <DbTable Name="ITEM_EVENT_TRPL_EXT" TablespaceName="PRIMARY">
      <Columns>
        <DbColumn Name="EVENT_GROUP_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ITEM_ID" Precision="32" PkOrder="1" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="EVENT_TYPE" Precision="14" PkOrder="2" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="PERIOD" Precision="20" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="START_DATETIME" PkOrder="6" IsIdentity="False" IsNullable="False" LogicalDbType="Date" />
        <DbColumn Name="END_DATETIME" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="KEY_EXT1" Precision="50" PkOrder="3" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="KEY_EXT2" Precision="50" PkOrder="4" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="KEY_EXT3" Precision="50" PkOrder="5" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="ITEM_REF1" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ITEM_REF2" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ITEM_REF3" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="VAL1" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL2" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL3" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL4" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL5" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL6" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL7" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL8" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL9" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL10" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL11" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL12" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL13" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL14" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL15" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL16" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL17" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL18" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL19" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL20" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="DATE1" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE2" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE3" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="CHAR1" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR2" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR3" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR4" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR5" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_USER" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_DATE" DefaultValueType="Now" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="VERSION" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="DB_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ROW_ID" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="STATUS" Precision="10" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="REV_GRP_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="UPDATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="CREATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
      </Columns>
      <Indexes>
        <DbIndex Name="IX_ITEM_EVENT_TRPL_EXT" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>EVENT_GROUP_ID</string>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
            <string>PERIOD</string>
            <string>START_DATETIME</string>
            <string>KEY_EXT1</string>
            <string>KEY_EXT2</string>
            <string>KEY_EXT3</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_TRPL_EXT2" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_TRPL_EXT3" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_TRPL_EXT_REF1" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_REF1</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_TRPL_EXT_REF2" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_REF2</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_TRPL_EXT_REF3" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_REF3</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_TRPL_EXT_TYPE" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>EVENT_TYPE</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_TRPL_EXT_RID" TablespaceName="PRIMARY" IsUnique="True">
          <ColumnNames>
            <string>ROW_ID</string>
          </ColumnNames>
        </DbIndex>
      </Indexes>
      <Fks>
        <DbFk Name="FK_ITEM_EVENT_TRPL_EXT_ITEM1" RefTableName="ITEM" UpdateRule="None" DeleteRule="None">
          <FkColumnNames>
            <string>ITEM_REF1</string>
          </FkColumnNames>
          <RefColumnNames>
            <string>ITEM_ID</string>
          </RefColumnNames>
        </DbFk>
        <DbFk Name="FK_ITEM_EVENT_TRPL_EXT_ITEM2" RefTableName="ITEM" UpdateRule="None" DeleteRule="None">
          <FkColumnNames>
            <string>ITEM_REF2</string>
          </FkColumnNames>
          <RefColumnNames>
            <string>ITEM_ID</string>
          </RefColumnNames>
        </DbFk>
        <DbFk Name="FK_ITEM_EVENT_TRPL_EXT_ITEM3" RefTableName="ITEM" UpdateRule="None" DeleteRule="None">
          <FkColumnNames>
            <string>ITEM_REF3</string>
          </FkColumnNames>
          <RefColumnNames>
            <string>ITEM_ID</string>
          </RefColumnNames>
        </DbFk>
      </Fks>
      <Triggers />
      <PrimaryKey Name="PK_ITEM_EVENT_TRPL_EXT" TablespaceName="PRIMARY" />
    </DbTable>
    <DbTable Name="ITEM_EVENT_SC_TRPL" TablespaceName="PRIMARY">
      <Columns>
        <DbColumn Name="EVENT_GROUP_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="SCENARIO_ID" Precision="32" PkOrder="1" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="ITEM_ID" Precision="32" PkOrder="3" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="EVENT_TYPE" Precision="14" PkOrder="2" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="PERIOD" Precision="20" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="START_DATETIME" PkOrder="7" IsIdentity="False" IsNullable="False" LogicalDbType="Date" />
        <DbColumn Name="END_DATETIME" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="KEY_EXT1" Precision="50" PkOrder="4" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="KEY_EXT2" Precision="50" PkOrder="5" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="KEY_EXT3" Precision="50" PkOrder="6" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="ITEM_REF1" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ITEM_REF2" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ITEM_REF3" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="VAL1" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL2" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL3" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL4" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL5" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL6" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL7" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL8" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL9" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL10" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL11" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL12" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL13" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL14" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL15" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL16" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL17" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL18" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL19" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL20" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="DATE1" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE2" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE3" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="CHAR1" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR2" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR3" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR4" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR5" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_USER" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_DATE" DefaultValueType="Now" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="VERSION" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="DB_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ROW_ID" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="STATUS" Precision="10" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="REV_GRP_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="UPDATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="CREATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
      </Columns>
      <Indexes>
        <DbIndex Name="IX_ITEM_EVENT_SC_TRPL" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>EVENT_GROUP_ID</string>
            <string>SCENARIO_ID</string>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
            <string>PERIOD</string>
            <string>START_DATETIME</string>
            <string>KEY_EXT1</string>
            <string>KEY_EXT2</string>
            <string>KEY_EXT3</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_SC_TRPL2" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>SCENARIO_ID</string>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_SC_TRPL3" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>SCENARIO_ID</string>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_SC_TRPL_REF1" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_REF1</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_SC_TRPL_REF2" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_REF2</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_SC_TRPL_REF3" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_REF3</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_SC_TRPL_TYPE" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>EVENT_TYPE</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_SC_TRPL_RID" TablespaceName="PRIMARY" IsUnique="True">
          <ColumnNames>
            <string>ROW_ID</string>
          </ColumnNames>
        </DbIndex>
      </Indexes>
      <Fks>
        <DbFk Name="FK_ITEM_EVENT_SC_TRPL_ITEM1" RefTableName="ITEM" UpdateRule="None" DeleteRule="None">
          <FkColumnNames>
            <string>ITEM_REF1</string>
          </FkColumnNames>
          <RefColumnNames>
            <string>ITEM_ID</string>
          </RefColumnNames>
        </DbFk>
        <DbFk Name="FK_ITEM_EVENT_SC_TRPL_ITEM2" RefTableName="ITEM" UpdateRule="None" DeleteRule="None">
          <FkColumnNames>
            <string>ITEM_REF2</string>
          </FkColumnNames>
          <RefColumnNames>
            <string>ITEM_ID</string>
          </RefColumnNames>
        </DbFk>
        <DbFk Name="FK_ITEM_EVENT_SC_TRPL_ITEM3" RefTableName="ITEM" UpdateRule="None" DeleteRule="None">
          <FkColumnNames>
            <string>ITEM_REF3</string>
          </FkColumnNames>
          <RefColumnNames>
            <string>ITEM_ID</string>
          </RefColumnNames>
        </DbFk>
      </Fks>
      <Triggers />
      <PrimaryKey Name="PK_ITEM_EVENT_SC_TRPL" TablespaceName="PRIMARY" />
    </DbTable>
    <DbTable Name="ITEM_EVENT_VAL" TablespaceName="PRIMARY">
      <Columns>
        <DbColumn Name="EVENT_GROUP_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ITEM_ID" Precision="32" PkOrder="2" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="EVENT_TYPE" Precision="14" PkOrder="1" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="PERIOD" Precision="20" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="START_DATETIME" PkOrder="3" IsIdentity="False" IsNullable="False" LogicalDbType="Date" />
        <DbColumn Name="END_DATETIME" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="VAL1" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL2" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL3" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL4" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL5" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL6" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL7" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL8" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL9" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL10" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL11" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL12" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL13" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL14" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL15" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL16" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL17" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL18" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL19" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL20" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL21" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL22" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL23" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL24" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL25" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL26" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL27" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL28" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL29" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL30" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL31" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL32" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL33" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL34" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL35" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL36" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL37" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL38" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL39" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL40" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL41" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL42" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL43" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL44" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL45" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL46" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL47" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL48" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL49" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL50" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL51" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL52" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL53" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL54" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL55" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL56" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL57" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL58" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL59" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL60" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL61" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL62" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL63" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL64" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL65" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL66" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL67" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL68" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL69" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL70" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL71" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL72" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL73" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL74" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL75" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL76" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL77" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL78" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL79" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL80" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL81" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL82" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL83" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL84" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL85" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL86" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL87" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL88" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL89" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL90" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="DATE1" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE2" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE3" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE4" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE5" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="CHAR1" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR2" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR3" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR4" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR5" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_USER" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_DATE" DefaultValueType="Now" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="VERSION" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="DB_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ROW_ID" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="STATUS" Precision="10" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="REV_GRP_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="UPDATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="CREATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
      </Columns>
      <Indexes>
        <DbIndex Name="IX_ITEM_EVENT_VAL" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>EVENT_GROUP_ID</string>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
            <string>PERIOD</string>
            <string>START_DATETIME</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_VAL2" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_VAL3" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_VAL_TYPE" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>EVENT_TYPE</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_VAL_RID" TablespaceName="PRIMARY" IsUnique="True">
          <ColumnNames>
            <string>ROW_ID</string>
          </ColumnNames>
        </DbIndex>
      </Indexes>
      <Fks />
      <Triggers />
      <PrimaryKey Name="PK_ITEM_EVENT_VAL" TablespaceName="PRIMARY" />
    </DbTable>
    <DbTable Name="ITEM_EVENT_TEXT" TablespaceName="PRIMARY">
      <Columns>
        <DbColumn Name="EVENT_GROUP_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ITEM_ID" Precision="32" PkOrder="2" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="EVENT_TYPE" Precision="14" PkOrder="1" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="PERIOD" Precision="20" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="START_DATETIME" PkOrder="3" IsIdentity="False" IsNullable="False" LogicalDbType="Date" />
        <DbColumn Name="END_DATETIME" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="VAL1" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL2" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL3" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL4" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL5" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL6" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL7" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL8" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL9" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL10" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL11" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL12" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL13" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL14" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL15" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL16" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL17" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL18" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL19" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL20" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL21" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL22" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL23" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL24" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL25" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL26" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL27" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL28" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL29" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL30" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="DATE1" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE2" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE3" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE4" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE5" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="CODE1" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CODE2" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CODE3" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CODE4" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CODE5" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CODE6" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CODE7" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CODE8" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CODE9" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CODE10" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CODE11" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CODE12" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CODE13" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CODE14" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CODE15" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CODE16" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CODE17" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CODE18" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CODE19" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CODE20" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CODE21" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CODE22" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CODE23" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CODE24" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CODE25" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CODE26" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CODE27" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CODE28" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CODE29" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CODE30" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR1" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR2" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR3" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR4" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR5" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LINE1" Precision="80" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LINE2" Precision="80" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LINE3" Precision="80" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LINE4" Precision="80" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LINE5" Precision="80" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LINE6" Precision="80" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LINE7" Precision="80" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LINE8" Precision="80" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LINE9" Precision="80" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LINE10" Precision="80" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LINE11" Precision="80" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LINE12" Precision="80" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LINE13" Precision="80" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LINE14" Precision="80" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LINE15" Precision="80" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LINE16" Precision="80" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LINE17" Precision="80" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LINE18" Precision="80" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LINE19" Precision="80" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LINE20" Precision="80" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_USER" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_DATE" DefaultValueType="Now" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="VERSION" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="DB_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ROW_ID" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="STATUS" Precision="10" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="REV_GRP_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="UPDATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="CREATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
      </Columns>
      <Indexes>
        <DbIndex Name="IX_ITEM_EVENT_TEXT" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
            <string>PERIOD</string>
            <string>START_DATETIME</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_TEXT2" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_TEXT3" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_TEXT_TYPE" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>EVENT_TYPE</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_TEXT_RID" TablespaceName="PRIMARY" IsUnique="True">
          <ColumnNames>
            <string>ROW_ID</string>
          </ColumnNames>
        </DbIndex>
      </Indexes>
      <Fks />
      <Triggers />
      <PrimaryKey Name="PK_ITEM_EVENT_TEXT" TablespaceName="PRIMARY" />
    </DbTable>
    <DbTable Name="ITEM_EVENT_SC_VAL" TablespaceName="PRIMARY">
      <Columns>
        <DbColumn Name="EVENT_GROUP_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="SCENARIO_ID" Precision="32" PkOrder="1" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="ITEM_ID" Precision="32" PkOrder="3" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="EVENT_TYPE" Precision="14" PkOrder="2" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="PERIOD" Precision="20" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="START_DATETIME" PkOrder="4" IsIdentity="False" IsNullable="False" LogicalDbType="Date" />
        <DbColumn Name="END_DATETIME" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="VAL1" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL2" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL3" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL4" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL5" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL6" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL7" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL8" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL9" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL10" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL11" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL12" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL13" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL14" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL15" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL16" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL17" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL18" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL19" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL20" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL21" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL22" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL23" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL24" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL25" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL26" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL27" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL28" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL29" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL30" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL31" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL32" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL33" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL34" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL35" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL36" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL37" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL38" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL39" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL40" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL41" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL42" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL43" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL44" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL45" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL46" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL47" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL48" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL49" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL50" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL51" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL52" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL53" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL54" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL55" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL56" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL57" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL58" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL59" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL60" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL61" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL62" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL63" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL64" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL65" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL66" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL67" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL68" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL69" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL70" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL71" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL72" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL73" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL74" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL75" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL76" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL77" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL78" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL79" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL80" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL81" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL82" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL83" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL84" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL85" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="DATE1" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE2" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE3" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE4" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE5" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="CHAR1" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR2" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR3" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR4" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR5" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_USER" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_DATE" DefaultValueType="Now" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="VERSION" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="DB_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ROW_ID" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="STATUS" Precision="10" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="REV_GRP_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="UPDATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="CREATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
      </Columns>
      <Indexes>
        <DbIndex Name="IX_ITEM_EVENT_VAL_SC" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>EVENT_GROUP_ID</string>
            <string>SCENARIO_ID</string>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
            <string>PERIOD</string>
            <string>START_DATETIME</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_VAL2_SC" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>SCENARIO_ID</string>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_VAL3_SC" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>SCENARIO_ID</string>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_VAL_TYPE_SC" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>EVENT_TYPE</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_VAL_SC_RID" TablespaceName="PRIMARY" IsUnique="True">
          <ColumnNames>
            <string>ROW_ID</string>
          </ColumnNames>
        </DbIndex>
      </Indexes>
      <Fks />
      <Triggers />
      <PrimaryKey Name="PK_ITEM_EVENT_VAL_SC" TablespaceName="PRIMARY" />
    </DbTable>
    <DbTable Name="ITEM_EVENT_WITH_REF" TablespaceName="PRIMARY">
      <Columns>
        <DbColumn Name="EVENT_GROUP_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ITEM_ID" Precision="32" PkOrder="1" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="EVENT_TYPE" Precision="14" PkOrder="2" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="PERIOD" Precision="20" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="START_DATETIME" PkOrder="3" IsIdentity="False" IsNullable="False" LogicalDbType="Date" />
        <DbColumn Name="END_DATETIME" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="ITEM_REF1" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ITEM_REF2" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ITEM_REF3" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ITEM_REF4" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ITEM_REF5" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="VAL1" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL2" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL3" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL4" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL5" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL6" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL7" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL8" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL9" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL10" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL11" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL12" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL13" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL14" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL15" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL16" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL17" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL18" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL19" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL20" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL21" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL22" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL23" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL24" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL25" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL26" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL27" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL28" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL29" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL30" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL31" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL32" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL33" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL34" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL35" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL36" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL37" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL38" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL39" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL40" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL41" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL42" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL43" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL44" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL45" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL46" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL47" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL48" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL49" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL50" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL51" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL52" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL53" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL54" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL55" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL56" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL57" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL58" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL59" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL60" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL61" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL62" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL63" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL64" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL65" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL66" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL67" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL68" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL69" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL70" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="DATE1" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE2" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE3" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE4" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE5" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="CHAR1" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR2" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR3" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR4" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR5" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR6" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR7" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR8" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR9" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR10" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR11" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR12" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR13" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR14" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR15" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_USER" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_DATE" DefaultValueType="Now" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="VERSION" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="DB_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ROW_ID" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="STATUS" Precision="10" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="REV_GRP_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="UPDATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="CREATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
      </Columns>
      <Indexes>
        <DbIndex Name="IX_ITEM_EVENT_WITH_REF" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>EVENT_GROUP_ID</string>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
            <string>PERIOD</string>
            <string>START_DATETIME</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_WITH_REF2" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_WITH_REF3" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_WITH_REF_REF1" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_REF1</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_WITH_REF_REF2" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_REF2</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_WITH_REF_REF3" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_REF3</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_WITH_REF_REF4" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_REF4</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_WITH_REF_REF5" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_REF5</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_WITH_REF_TYPE" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>EVENT_TYPE</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_EVENT_WITH_REF_RID" TablespaceName="PRIMARY" IsUnique="True">
          <ColumnNames>
            <string>ROW_ID</string>
          </ColumnNames>
        </DbIndex>
      </Indexes>
      <Fks>
        <DbFk Name="FK_ITEM_EVENT_WITH_REF_ITEM1" RefTableName="ITEM" UpdateRule="None" DeleteRule="None">
          <FkColumnNames>
            <string>ITEM_REF1</string>
          </FkColumnNames>
          <RefColumnNames>
            <string>ITEM_ID</string>
          </RefColumnNames>
        </DbFk>
        <DbFk Name="FK_ITEM_EVENT_WITH_REF_ITEM2" RefTableName="ITEM" UpdateRule="None" DeleteRule="None">
          <FkColumnNames>
            <string>ITEM_REF2</string>
          </FkColumnNames>
          <RefColumnNames>
            <string>ITEM_ID</string>
          </RefColumnNames>
        </DbFk>
        <DbFk Name="FK_ITEM_EVENT_WITH_REF_ITEM3" RefTableName="ITEM" UpdateRule="None" DeleteRule="None">
          <FkColumnNames>
            <string>ITEM_REF3</string>
          </FkColumnNames>
          <RefColumnNames>
            <string>ITEM_ID</string>
          </RefColumnNames>
        </DbFk>
        <DbFk Name="FK_ITEM_EVENT_WITH_REF_ITEM4" RefTableName="ITEM" UpdateRule="None" DeleteRule="None">
          <FkColumnNames>
            <string>ITEM_REF4</string>
          </FkColumnNames>
          <RefColumnNames>
            <string>ITEM_ID</string>
          </RefColumnNames>
        </DbFk>
        <DbFk Name="FK_ITEM_EVENT_WITH_REF_ITEM5" RefTableName="ITEM" UpdateRule="None" DeleteRule="None">
          <FkColumnNames>
            <string>ITEM_REF5</string>
          </FkColumnNames>
          <RefColumnNames>
            <string>ITEM_ID</string>
          </RefColumnNames>
        </DbFk>
      </Fks>
      <Triggers />
      <PrimaryKey Name="PK_ITEM_EVENT_WITH_REF" TablespaceName="PRIMARY" />
    </DbTable>
    <DbTable Name="ITEM_LINK" TablespaceName="PRIMARY">
      <Columns>
        <DbColumn Name="LINK_ID" Precision="32" DefaultValueType="Guid" PkOrder="6" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="LINK_TYPE" Precision="14" PkOrder="1" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="START_DATETIME" PkOrder="4" IsIdentity="False" IsNullable="False" LogicalDbType="Date" />
        <DbColumn Name="END_DATETIME" DefaultValueType="EndDatetime" PkOrder="5" IsIdentity="False" IsNullable="False" LogicalDbType="Date" />
        <DbColumn Name="FROM_ITEM_ID" Precision="32" PkOrder="2" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="FROM_ITEM_TYPE" Precision="14" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="TO_ITEM_ID" Precision="32" PkOrder="3" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="TO_ITEM_TYPE" Precision="14" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="COLL_ITEM_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="COLL_ITEM_TYPE" Precision="14" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="LAST_UPDT_USER" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_DATE" DefaultValueType="Now" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="VERSION" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="DB_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ROW_ID" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="STATUS" Precision="10" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="REV_GRP_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="UPDATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="CREATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
      </Columns>
      <Indexes>
        <DbIndex Name="IX_ITEM_LINK_LINK_ID" TablespaceName="PRIMARY" IsUnique="True">
          <ColumnNames>
            <string>LINK_ID</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_LINK1" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>LINK_TYPE</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
            <string>TO_ITEM_TYPE</string>
            <string>TO_ITEM_ID</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_LINK2" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>LINK_TYPE</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
            <string>FROM_ITEM_TYPE</string>
            <string>FROM_ITEM_ID</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_LINK3" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>LINK_TYPE</string>
            <string>COLL_ITEM_ID</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_LINK4" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>LINK_TYPE</string>
            <string>TO_ITEM_ID</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
            <string>FROM_ITEM_ID</string>
            <string>LINK_ID</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_LINK5" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>LINK_TYPE</string>
            <string>FROM_ITEM_ID</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
            <string>TO_ITEM_ID</string>
            <string>LINK_ID</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_LINK6" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>LINK_TYPE</string>
            <string>COLL_ITEM_ID</string>
            <string>COLL_ITEM_TYPE</string>
            <string>END_DATETIME</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_LINK_RID" TablespaceName="PRIMARY" IsUnique="True">
          <ColumnNames>
            <string>ROW_ID</string>
          </ColumnNames>
        </DbIndex>
      </Indexes>
      <Fks />
      <Triggers />
      <PrimaryKey Name="PK_ITEM_LINK" TablespaceName="PRIMARY" />
    </DbTable>
    <DbTable Name="ITEM_LINK_PROPERTY" TablespaceName="PRIMARY">
      <Columns>
        <DbColumn Name="LINK_ID" Precision="32" PkOrder="1" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="LINK_TYPE" Precision="14" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="START_DATETIME" PkOrder="2" IsIdentity="False" IsNullable="False" LogicalDbType="Date" />
        <DbColumn Name="END_DATETIME" DefaultValueType="EndDatetime" PkOrder="3" IsIdentity="False" IsNullable="False" LogicalDbType="Date" />
        <DbColumn Name="PROPERTY_TYPE" Precision="15" PkOrder="4" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="PROPERTY_VALUE" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="PROPERTY_DATE" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="PROPERTY_STRING" Precision="200" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_USER" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_DATE" DefaultValueType="Now" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="VERSION" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="DB_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ROW_ID" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="STATUS" Precision="10" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="REV_GRP_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="UPDATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="CREATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
      </Columns>
      <Indexes>
        <DbIndex Name="IX_ITEM_LINK_PROPERTY_1" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>PROPERTY_STRING</string>
            <string>LINK_TYPE</string>
            <string>PROPERTY_TYPE</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
            <string>LINK_ID</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_LINK_PROPERTY_2" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>PROPERTY_VALUE</string>
            <string>LINK_TYPE</string>
            <string>PROPERTY_TYPE</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
            <string>LINK_ID</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_LINK_PROPERTY_3" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>PROPERTY_DATE</string>
            <string>LINK_TYPE</string>
            <string>PROPERTY_TYPE</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
            <string>LINK_ID</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_LINK_PROPERTY4" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>LINK_ID</string>
            <string>PROPERTY_TYPE</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
            <string>PROPERTY_STRING</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_LINK_PROPERTY5" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>LINK_ID</string>
            <string>PROPERTY_TYPE</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
            <string>PROPERTY_VALUE</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_LINK_PROPERTY6" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>LINK_ID</string>
            <string>PROPERTY_TYPE</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
            <string>PROPERTY_DATE</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_LINK_PROPERTY_RID" TablespaceName="PRIMARY" IsUnique="True">
          <ColumnNames>
            <string>ROW_ID</string>
          </ColumnNames>
        </DbIndex>
      </Indexes>
      <Fks>
        <DbFk Name="FK_ITEM_LINK_PROP_ITEM_LINK" RefTableName="ITEM_LINK" UpdateRule="Cascade" DeleteRule="Cascade">
          <FkColumnNames>
            <string>LINK_ID</string>
          </FkColumnNames>
          <RefColumnNames>
            <string>LINK_ID</string>
          </RefColumnNames>
        </DbFk>
      </Fks>
      <Triggers />
      <PrimaryKey Name="PK_ITEM_LINK_PROPERTY" TablespaceName="PRIMARY" />
    </DbTable>
    <DbTable Name="ITEM_PROPERTY" TablespaceName="PRIMARY">
      <Columns>
        <DbColumn Name="ITEM_ID" Precision="32" PkOrder="1" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="ITEM_TYPE" Precision="14" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="START_DATETIME" PkOrder="3" IsIdentity="False" IsNullable="False" LogicalDbType="Date" />
        <DbColumn Name="END_DATETIME" DefaultValueType="EndDatetime" PkOrder="4" IsIdentity="False" IsNullable="False" LogicalDbType="Date" />
        <DbColumn Name="PROPERTY_TYPE" Precision="15" PkOrder="2" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="PROPERTY_VALUE" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="PROPERTY_DATE" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="PROPERTY_STRING" Precision="200" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_USER" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_DATE" DefaultValueType="Now" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="VERSION" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="DB_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ROW_ID" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="STATUS" Precision="10" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="REV_GRP_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="UPDATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="CREATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
      </Columns>
      <Indexes>
        <DbIndex Name="IX_ITEM_PROPERTY_1" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>PROPERTY_STRING</string>
            <string>ITEM_TYPE</string>
            <string>PROPERTY_TYPE</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
            <string>ITEM_ID</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_PROPERTY_2" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>PROPERTY_VALUE</string>
            <string>ITEM_TYPE</string>
            <string>PROPERTY_TYPE</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
            <string>ITEM_ID</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_PROPERTY_3" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>PROPERTY_DATE</string>
            <string>ITEM_TYPE</string>
            <string>PROPERTY_TYPE</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
            <string>ITEM_ID</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_PROPERTY4" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_ID</string>
            <string>PROPERTY_TYPE</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
            <string>PROPERTY_STRING</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_PROPERTY5" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_ID</string>
            <string>PROPERTY_TYPE</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
            <string>PROPERTY_VALUE</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_PROPERTY6" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_ID</string>
            <string>PROPERTY_TYPE</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
            <string>PROPERTY_DATE</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_PROPERTY_RID" TablespaceName="PRIMARY" IsUnique="True">
          <ColumnNames>
            <string>ROW_ID</string>
          </ColumnNames>
        </DbIndex>
      </Indexes>
      <Fks>
        <DbFk Name="FK_ITEM_PROPERTY_ITEM" RefTableName="ITEM" UpdateRule="None" DeleteRule="Cascade">
          <FkColumnNames>
            <string>ITEM_ID</string>
          </FkColumnNames>
          <RefColumnNames>
            <string>ITEM_ID</string>
          </RefColumnNames>
        </DbFk>
      </Fks>
      <Triggers />
      <PrimaryKey Name="PK_ITEM_PROPERTY" TablespaceName="PRIMARY" />
    </DbTable>
    <DbTable Name="ITEM_TEMP_CACHE" TablespaceName="PRIMARY">
      <Columns>
        <DbColumn Name="CACHE_ID" Precision="32" PkOrder="1" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="ITEM_ID" Precision="32" PkOrder="2" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="ITEM_TYPE" Precision="14" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="GROUP_TYPE" Precision="14" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="LAST_UPDT_DATE" DefaultValueType="Now" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
      </Columns>
      <Indexes>
        <DbIndex Name="IX_ITEM_TEMP_CACHE_1" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>CACHE_ID</string>
            <string>GROUP_TYPE</string>
            <string>ITEM_ID</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_TEMP_CACHE_2" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>CACHE_ID</string>
            <string>ITEM_TYPE</string>
            <string>ITEM_ID</string>
          </ColumnNames>
        </DbIndex>
      </Indexes>
      <Fks />
      <Triggers />
      <PrimaryKey Name="PK_ITEM_TEMP_CACHE" TablespaceName="PRIMARY" />
    </DbTable>
    <DbTable Name="ITEM_VERSION" TablespaceName="PRIMARY">
      <Columns>
        <DbColumn Name="ITEM_ID" Precision="32" PkOrder="1" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="START_DATETIME" PkOrder="2" IsIdentity="False" IsNullable="False" LogicalDbType="Date" />
        <DbColumn Name="END_DATETIME" DefaultValueType="EndDatetime" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="LAST_UPDT_USER" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_DATE" DefaultValueType="Now" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="VERSION" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="DB_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ROW_ID" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="STATUS" Precision="10" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="REV_GRP_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="UPDATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="CREATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
      </Columns>
      <Indexes>
        <DbIndex Name="IX_ITEM_VERSION_RID" TablespaceName="PRIMARY" IsUnique="True">
          <ColumnNames>
            <string>ROW_ID</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_ITEM_VERSION_1" TablespaceName="PRIMARY" IsUnique="True">
          <ColumnNames>
            <string>ITEM_ID</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
          </ColumnNames>
        </DbIndex>
      </Indexes>
      <Fks />
      <Triggers />
      <PrimaryKey Name="PK_ITEM_VERSION" TablespaceName="PRIMARY" />
    </DbTable>
    <DbTable Name="LAYER" TablespaceName="PRIMARY">
      <Columns>
        <DbColumn Name="LAYER_NAME" Precision="100" PkOrder="1" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="LAYER_LEVEL" Precision="100" IsIdentity="False" IsNullable="False" LogicalDbType="Unicode" />
        <DbColumn Name="LAYER_ORDER" Precision="18" Scale="0" IsIdentity="False" IsNullable="False" LogicalDbType="NumericData" />
        <DbColumn Name="LAST_UPDT_USER" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_DATE" DefaultValueType="Now" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="VERSION" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="DB_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ROW_ID" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="STATUS" Precision="10" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="REV_GRP_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
      </Columns>
      <Indexes />
      <Fks />
      <Triggers />
      <PrimaryKey Name="PK_LAYER" TablespaceName="PRIMARY" />
    </DbTable>
    <DbTable Name="LOG_ROWS" TablespaceName="PRIMARY">
      <Columns>
        <DbColumn Name="LOG_SEQ" Precision="10" Scale="0" PkOrder="1" IsIdentity="True" IsNullable="False" LogicalDbType="LargeInteger" />
        <DbColumn Name="DB_ID" Precision="32" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="TABLE_NAME" Precision="50" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="TYPE" Precision="14" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="PROPERTY_NAME" Precision="15" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="ITEM_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ROW_ID" Precision="32" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="ACTION" Precision="1" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="END_UPDT" Precision="1" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="DATA_SOURCE" Precision="1" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="VERSION" Precision="32" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="ROW_STATUS" Precision="10" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="LAST_UPDT_DATE" DefaultValueType="Now" IsIdentity="False" IsNullable="False" LogicalDbType="Date" />
        <DbColumn Name="START_DATETIME" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="END_DATETIME" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="PK_CHAR1" Precision="255" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="PK_CHAR2" Precision="255" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="PK_CHAR3" Precision="255" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="PK_CHAR4" Precision="255" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="PK_CHAR5" Precision="255" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="PK_CHAR6" Precision="255" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="PK_CHAR7" Precision="255" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="PK_DATE1" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="PK_DATE2" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="PK_DATE3" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="PK_VAL1" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="PK_VAL2" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
      </Columns>
      <Indexes />
      <Fks />
      <Triggers />
      <PrimaryKey Name="PK_LOG_ROWS" TablespaceName="PRIMARY" />
    </DbTable>
    <DbTable Name="RESOURCE_LIST" TablespaceName="PRIMARY">
      <Columns>
        <DbColumn Name="CULTURE" Precision="10" PkOrder="1" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="ID" Precision="100" PkOrder="2" IsIdentity="False" IsNullable="False" LogicalDbType="Unicode" />
        <DbColumn Name="SHORT_LABEL" Precision="200" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="MOBILE_LABEL" Precision="200" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAYER_NAME" Precision="50" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="HIDDEN" Precision="5" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="LAST_UPDT_USER" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_DATE" DefaultValueType="Now" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="VERSION" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="DB_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ROW_ID" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="STATUS" Precision="10" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="REV_GRP_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
      </Columns>
      <Indexes>
        <DbIndex Name="IX_RESOURCE_LIST_RID" TablespaceName="PRIMARY" IsUnique="True">
          <ColumnNames>
            <string>ROW_ID</string>
          </ColumnNames>
        </DbIndex>
      </Indexes>
      <Fks />
      <Triggers />
      <PrimaryKey Name="PK_RESOURCE_LIST" TablespaceName="PRIMARY" />
    </DbTable>
    <DbTable Name="RESOURCE_LIST_LAYER" TablespaceName="PRIMARY">
      <Columns>
        <DbColumn Name="CULTURE" Precision="10" PkOrder="1" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="ID" Precision="100" PkOrder="2" IsIdentity="False" IsNullable="False" LogicalDbType="Unicode" />
        <DbColumn Name="SHORT_LABEL" Precision="200" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="MOBILE_LABEL" Precision="200" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAYER_NAME" Precision="50" PkOrder="3" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="HIDDEN" Precision="5" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="LAST_UPDT_USER" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_DATE" DefaultValueType="Now" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="VERSION" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="DB_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ROW_ID" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="STATUS" Precision="10" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="REV_GRP_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
      </Columns>
      <Indexes>
        <DbIndex Name="IX_RESOURCE_LIST_LAYER_RID" TablespaceName="PRIMARY" IsUnique="True">
          <ColumnNames>
            <string>ROW_ID</string>
          </ColumnNames>
        </DbIndex>
      </Indexes>
      <Fks />
      <Triggers />
      <PrimaryKey Name="PK_RESOURCE_LIST_LAYER" TablespaceName="PRIMARY" />
    </DbTable>
    <DbTable Name="STRING_TEMP_CACHE" TablespaceName="PRIMARY">
      <Columns>
        <DbColumn Name="CACHE_ID" Precision="32" PkOrder="1" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="TEMP_STRING" Precision="50" PkOrder="2" IsIdentity="False" IsNullable="False" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_DATE" DefaultValueType="Now" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
      </Columns>
      <Indexes />
      <Fks />
      <Triggers />
      <PrimaryKey Name="PK_STRING_TEMP_CACHE" TablespaceName="PRIMARY" />
    </DbTable>
    <DbTable Name="TAG_VALUES" TablespaceName="PRIMARY">
      <Columns>
        <DbColumn Name="TAG_ID" Precision="255" PkOrder="1" IsIdentity="False" IsNullable="False" LogicalDbType="Unicode" />
        <DbColumn Name="TIMESTAMP" PkOrder="2" IsIdentity="False" IsNullable="False" LogicalDbType="Date2" />
        <DbColumn Name="TAG_VALUE" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="TAG_STRING" Precision="200" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="TAG_DATE" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="QUALITY" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
      </Columns>
      <Indexes />
      <Fks />
      <Triggers />
      <PrimaryKey Name="PK_TAG_VALUES" TablespaceName="PRIMARY" />
    </DbTable>
    <DbTable Name="TASK_STATUS" TablespaceName="PRIMARY">
      <Columns>
        <DbColumn Name="EVENT_GROUP_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ITEM_ID" Precision="32" PkOrder="1" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="EVENT_TYPE" Precision="14" PkOrder="2" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="PERIOD" Precision="20" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="START_DATETIME" PkOrder="3" IsIdentity="False" IsNullable="False" LogicalDbType="Date" />
        <DbColumn Name="END_DATETIME" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="KEY_EXT1" Precision="50" PkOrder="4" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="KEY_EXT2" Precision="50" PkOrder="5" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="ITEM_REF1" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ITEM_REF2" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ITEM_REF3" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="CHAR1" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR2" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR3" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR4" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR5" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_USER" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_DATE" DefaultValueType="Now" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="VERSION" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="DB_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ROW_ID" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="STATUS" Precision="10" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="REV_GRP_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="UPDATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="CREATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
      </Columns>
      <Indexes>
        <DbIndex Name="IX_TASK_STATUS_REF1" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_REF1</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_TASK_STATUS_REF2" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_REF2</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_TASK_STATUS_REF3" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_REF3</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_TASK_STATUS_RID" TablespaceName="PRIMARY" IsUnique="True">
          <ColumnNames>
            <string>ROW_ID</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_TASK_STATUS_TYPE" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>EVENT_TYPE</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_TASK_STATUS1" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_TASK_STATUS2" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
          </ColumnNames>
        </DbIndex>
      </Indexes>
      <Fks>
        <DbFk Name="FK_TASK_STATUS_ITEM1" RefTableName="ITEM" UpdateRule="None" DeleteRule="None">
          <FkColumnNames>
            <string>ITEM_ID</string>
          </FkColumnNames>
          <RefColumnNames>
            <string>ITEM_ID</string>
          </RefColumnNames>
        </DbFk>
        <DbFk Name="FK_TASK_STATUS_REF1" RefTableName="ITEM" UpdateRule="None" DeleteRule="None">
          <FkColumnNames>
            <string>ITEM_REF1</string>
          </FkColumnNames>
          <RefColumnNames>
            <string>ITEM_ID</string>
          </RefColumnNames>
        </DbFk>
        <DbFk Name="FK_TASK_STATUS_REF2" RefTableName="ITEM" UpdateRule="None" DeleteRule="None">
          <FkColumnNames>
            <string>ITEM_REF2</string>
          </FkColumnNames>
          <RefColumnNames>
            <string>ITEM_ID</string>
          </RefColumnNames>
        </DbFk>
        <DbFk Name="FK_TASK_STATUS_REF3" RefTableName="ITEM" UpdateRule="None" DeleteRule="None">
          <FkColumnNames>
            <string>ITEM_REF3</string>
          </FkColumnNames>
          <RefColumnNames>
            <string>ITEM_ID</string>
          </RefColumnNames>
        </DbFk>
      </Fks>
      <Triggers />
      <PrimaryKey Name="PK_TASK_STATUS" TablespaceName="PRIMARY" />
    </DbTable>
    <DbTable Name="TYPE" TablespaceName="PRIMARY">
      <Columns>
        <DbColumn Name="TYPE" Precision="14" PkOrder="1" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="TYPE_CLASS" Precision="50" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="LABEL_ID" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHANGE_INTERVAL" Precision="10" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="LAYER_NAME" Precision="50" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="DESCRIPTION_ID" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="HIDDEN" Precision="5" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="BASE_TYPE" Precision="14" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="CODE_LIST_TYPE" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="IS_QUICK_LINK" Precision="5" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="PROP_TBL_NAME" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="BASE_TBL_NAME" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="TAG_TBL_NAME" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="LAST_UPDT_USER" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_DATE" DefaultValueType="Now" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="VERSION" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="DB_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ROW_ID" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="STATUS" Precision="10" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="REV_GRP_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
      </Columns>
      <Indexes>
        <DbIndex Name="IX_TYPE_RID" TablespaceName="PRIMARY" IsUnique="True">
          <ColumnNames>
            <string>ROW_ID</string>
          </ColumnNames>
        </DbIndex>
      </Indexes>
      <Fks />
      <Triggers />
      <PrimaryKey Name="PK_TYPE" TablespaceName="PRIMARY" />
    </DbTable>
    <DbTable Name="TYPE_AUDIT" TablespaceName="PRIMARY">
      <Columns>
        <DbColumn Name="TYPE" Precision="14" PkOrder="1" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="ROW_STATUS" Precision="10" PkOrder="2" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="LAST_UPDT_USER" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_DATE" DefaultValueType="Now" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="VERSION" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="DB_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ROW_ID" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="STATUS" Precision="10" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="REV_GRP_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
      </Columns>
      <Indexes />
      <Fks />
      <Triggers />
      <PrimaryKey Name="PK_TYPE_AUDIT" TablespaceName="PRIMARY" />
    </DbTable>
    <DbTable Name="TYPE_LAYER" TablespaceName="PRIMARY">
      <Columns>
        <DbColumn Name="TYPE" Precision="14" PkOrder="1" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="TYPE_CLASS" Precision="50" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="LABEL_ID" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHANGE_INTERVAL" Precision="10" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="LAYER_NAME" Precision="50" PkOrder="2" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="DESCRIPTION_ID" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="HIDDEN" Precision="5" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="BASE_TYPE" Precision="14" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="CODE_LIST_TYPE" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="IS_QUICK_LINK" Precision="5" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="PROP_TBL_NAME" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="BASE_TBL_NAME" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="TAG_TBL_NAME" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="LAST_UPDT_USER" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_DATE" DefaultValueType="Now" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="VERSION" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="DB_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ROW_ID" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="STATUS" Precision="10" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="REV_GRP_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
      </Columns>
      <Indexes>
        <DbIndex Name="IX_TYPE_LAYER_RID" TablespaceName="PRIMARY" IsUnique="True">
          <ColumnNames>
            <string>ROW_ID</string>
          </ColumnNames>
        </DbIndex>
      </Indexes>
      <Fks />
      <Triggers />
      <PrimaryKey Name="PK_TYPE_LAYER" TablespaceName="PRIMARY" />
    </DbTable>
    <DbTable Name="TYPE_LINK" TablespaceName="PRIMARY">
      <Columns>
        <DbColumn Name="TYPE" Precision="14" PkOrder="1" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="FROM_TYPE" Precision="14" PkOrder="2" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="FROM_TYPE_CLASS" Precision="50" PkOrder="3" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="FROM_CARDINALITY" Precision="10" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="TO_TYPE" Precision="14" PkOrder="4" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="TO_TYPE_CLASS" Precision="50" PkOrder="5" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="TO_CARDINALITY" Precision="10" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="COLL_TYPE" Precision="14" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="COLL_TYPE_CLASS" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="SYSTEM" Precision="5" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="MANDATORY" Precision="5" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="RELATION_EDIT_CLASS" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="LAYER_NAME" Precision="50" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="DESCRIPTION_ID" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="HIDDEN" Precision="5" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="LAST_UPDT_USER" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_DATE" DefaultValueType="Now" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="VERSION" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="DB_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ROW_ID" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="STATUS" Precision="10" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="REV_GRP_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
      </Columns>
      <Indexes>
        <DbIndex Name="IX_TYPE_LINK_RID" TablespaceName="PRIMARY" IsUnique="True">
          <ColumnNames>
            <string>ROW_ID</string>
          </ColumnNames>
        </DbIndex>
      </Indexes>
      <Fks />
      <Triggers />
      <PrimaryKey Name="PK_TYPE_LINK" TablespaceName="PRIMARY" />
    </DbTable>
    <DbTable Name="TYPE_LINK_LAYER" TablespaceName="PRIMARY">
      <Columns>
        <DbColumn Name="TYPE" Precision="14" PkOrder="1" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="FROM_TYPE" Precision="14" PkOrder="2" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="FROM_TYPE_CLASS" Precision="50" PkOrder="3" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="FROM_CARDINALITY" Precision="10" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="TO_TYPE" Precision="14" PkOrder="4" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="TO_TYPE_CLASS" Precision="50" PkOrder="5" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="TO_CARDINALITY" Precision="10" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="COLL_TYPE" Precision="14" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="COLL_TYPE_CLASS" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="SYSTEM" Precision="5" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="MANDATORY" Precision="5" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="RELATION_EDIT_CLASS" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="LAYER_NAME" Precision="50" PkOrder="6" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="DESCRIPTION_ID" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="HIDDEN" Precision="5" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="LAST_UPDT_USER" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_DATE" DefaultValueType="Now" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="VERSION" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="DB_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ROW_ID" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="STATUS" Precision="10" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="REV_GRP_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
      </Columns>
      <Indexes>
        <DbIndex Name="IX_TYPE_LINK_LAYER_RID" TablespaceName="PRIMARY" IsUnique="True">
          <ColumnNames>
            <string>ROW_ID</string>
          </ColumnNames>
        </DbIndex>
      </Indexes>
      <Fks />
      <Triggers />
      <PrimaryKey Name="PK_TYPE_LINK_LAYER" TablespaceName="PRIMARY" />
    </DbTable>
    <DbTable Name="TYPE_PROPERTY" TablespaceName="PRIMARY">
      <Columns>
        <DbColumn Name="TYPE" Precision="14" PkOrder="1" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="PROPERTY_NAME" Precision="15" PkOrder="2" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="PROP_GRP" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="PROP_GRP_PRNT" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="LABEL_ID" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="TABLE_NAME" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="COLUMN_NAME" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="PROPERTY_TYPE" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="PROPERTY_CLASS" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="UNICODE" Precision="5" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="CODE_LIST" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="CODE_LIST_FLTR" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CODE_LIST_LVL" Precision="18" Scale="0" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="PARENT_CL_PROP" Precision="15" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="VALUE_FILTER" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="UI_EDIT_CLASS" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="SORT_ORDER" Precision="18" Scale="0" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="MANDATORY" Precision="5" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="HIDDEN" Precision="5" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="IS_KEY" Precision="5" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="LENGTH" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="DECIMALS" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="UOM" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="CHANGE_INTERVAL" Precision="10" DefaultValueType="ChangeInterval" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="DEFAULT_VALUE" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="LAYER_NAME" Precision="50" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="DESCRIPTION_ID" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_USER" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_DATE" DefaultValueType="Now" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="VERSION" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="DB_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ROW_ID" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="STATUS" Precision="10" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="REV_GRP_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="PROP_UNIQUE" Precision="20" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="ALLOW_MULTI_EDIT" Precision="5" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="DEF_ACCUM_FUNC" Precision="20" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
      </Columns>
      <Indexes>
        <DbIndex Name="IX_TYPE_PROPERTY_RID" TablespaceName="PRIMARY" IsUnique="True">
          <ColumnNames>
            <string>ROW_ID</string>
          </ColumnNames>
        </DbIndex>
      </Indexes>
      <Fks />
      <Triggers />
      <PrimaryKey Name="PK_TYPE_PROPERTY" TablespaceName="PRIMARY" />
    </DbTable>
    <DbTable Name="TYPE_PROPERTY_LAYER" TablespaceName="PRIMARY">
      <Columns>
        <DbColumn Name="TYPE" Precision="14" PkOrder="1" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="PROPERTY_NAME" Precision="15" PkOrder="2" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="PROP_GRP" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="PROP_GRP_PRNT" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="LABEL_ID" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="TABLE_NAME" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="COLUMN_NAME" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="PROPERTY_TYPE" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="PROPERTY_CLASS" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="UNICODE" Precision="5" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="CODE_LIST" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="CODE_LIST_FLTR" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CODE_LIST_LVL" Precision="18" Scale="0" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="PARENT_CL_PROP" Precision="15" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="VALUE_FILTER" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="UI_EDIT_CLASS" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="SORT_ORDER" Precision="18" Scale="0" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="MANDATORY" Precision="5" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="HIDDEN" Precision="5" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="IS_KEY" Precision="5" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="LENGTH" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="DECIMALS" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="UOM" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="CHANGE_INTERVAL" Precision="10" DefaultValueType="ChangeInterval" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="DEFAULT_VALUE" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="LAYER_NAME" Precision="50" PkOrder="3" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="DESCRIPTION_ID" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_USER" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_DATE" DefaultValueType="Now" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="VERSION" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="DB_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ROW_ID" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="STATUS" Precision="10" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="REV_GRP_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="PROP_UNIQUE" Precision="20" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="ALLOW_MULTI_EDIT" Precision="5" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="DEF_ACCUM_FUNC" Precision="20" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
      </Columns>
      <Indexes>
        <DbIndex Name="IX_TYPE_PROPERTY_LAYER_RID" TablespaceName="PRIMARY" IsUnique="True">
          <ColumnNames>
            <string>ROW_ID</string>
          </ColumnNames>
        </DbIndex>
      </Indexes>
      <Fks />
      <Triggers />
      <PrimaryKey Name="PK_TYPE_PROPERTY_LAYER" TablespaceName="PRIMARY" />
    </DbTable>
    <DbTable Name="TYPE_REF" TablespaceName="PRIMARY">
      <Columns>
        <DbColumn Name="TYPE" Precision="14" PkOrder="1" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="PROPERTY_NAME" Precision="15" PkOrder="2" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="VALID_TYPE" Precision="14" PkOrder="3" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="LAYER_NAME" Precision="50" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="DESCRIPTION_ID" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="HIDDEN" Precision="5" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="LAST_UPDT_USER" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_DATE" DefaultValueType="Now" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="VERSION" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="DB_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ROW_ID" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="STATUS" Precision="10" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="REV_GRP_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
      </Columns>
      <Indexes>
        <DbIndex Name="IX_TYPE_REF_RID" TablespaceName="PRIMARY" IsUnique="True">
          <ColumnNames>
            <string>ROW_ID</string>
          </ColumnNames>
        </DbIndex>
      </Indexes>
      <Fks />
      <Triggers />
      <PrimaryKey Name="PK_TYPE_REF" TablespaceName="PRIMARY" />
    </DbTable>
    <DbTable Name="TYPE_REF_LAYER" TablespaceName="PRIMARY">
      <Columns>
        <DbColumn Name="TYPE" Precision="14" PkOrder="1" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="PROPERTY_NAME" Precision="15" PkOrder="2" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="VALID_TYPE" Precision="14" PkOrder="3" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="LAYER_NAME" Precision="50" PkOrder="4" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="DESCRIPTION_ID" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="HIDDEN" Precision="5" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="LAST_UPDT_USER" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_DATE" DefaultValueType="Now" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="VERSION" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="DB_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ROW_ID" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="STATUS" Precision="10" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="REV_GRP_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
      </Columns>
      <Indexes>
        <DbIndex Name="IX_TYPE_REF_LAYER_RID" TablespaceName="PRIMARY" IsUnique="True">
          <ColumnNames>
            <string>ROW_ID</string>
          </ColumnNames>
        </DbIndex>
      </Indexes>
      <Fks />
      <Triggers />
      <PrimaryKey Name="PK_TYPE_REF_LAYER" TablespaceName="PRIMARY" />
    </DbTable>
    <DbTable Name="VERSION" TablespaceName="PRIMARY">
      <Columns>
        <DbColumn Name="VER_TYPE" Precision="100" PkOrder="1" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="VER_KEY" Precision="100" PkOrder="2" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="VER_GUID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="VER_NUMBER" Precision="28" Scale="12" DefaultValueType="Zero" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VER_STRING" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
      </Columns>
      <Indexes />
      <Fks />
      <Triggers />
      <PrimaryKey Name="PK_VERSION" TablespaceName="PRIMARY" />
    </DbTable>
    <DbTable Name="TYPE_UOM" TablespaceName="PRIMARY">
      <Columns>
        <DbColumn Name="PROPERTY_CLASS" Precision="100" PkOrder="1" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="UOM" Precision="50" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="LENGTH" Precision="28" Scale="12" IsIdentity="False" IsNullable="False" LogicalDbType="NumericData" />
        <DbColumn Name="DECIMALS" Precision="28" Scale="12" IsIdentity="False" IsNullable="False" LogicalDbType="NumericData" />
        <DbColumn Name="LAYER_NAME" Precision="50" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="ROW_ID" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="LAST_UPDT_USER" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_DATE" DefaultValueType="Now" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="VERSION" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="DB_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="STATUS" Precision="10" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="REV_GRP_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
      </Columns>
      <Indexes>
        <DbIndex Name="IX_TYPE_UOM_RID" TablespaceName="PRIMARY" IsUnique="True">
          <ColumnNames>
            <string>ROW_ID</string>
          </ColumnNames>
        </DbIndex>
      </Indexes>
      <Fks />
      <Triggers />
      <PrimaryKey Name="PK_TYPE_UOM" TablespaceName="PRIMARY" />
    </DbTable>
    <DbTable Name="TYPE_UOM_LAYER" TablespaceName="PRIMARY">
      <Columns>
        <DbColumn Name="PROPERTY_CLASS" Precision="100" PkOrder="1" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="UOM" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="LENGTH" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="DECIMALS" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="LAYER_NAME" Precision="50" PkOrder="2" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="ROW_ID" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="LAST_UPDT_USER" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_DATE" DefaultValueType="Now" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="VERSION" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="DB_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="STATUS" Precision="10" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="REV_GRP_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
      </Columns>
      <Indexes>
        <DbIndex Name="IX_TYPE_UOM_LAYER_RID" TablespaceName="PRIMARY" IsUnique="True">
          <ColumnNames>
            <string>ROW_ID</string>
          </ColumnNames>
        </DbIndex>
      </Indexes>
      <Fks />
      <Triggers />
      <PrimaryKey Name="PK_TYPE_UOM_LAYER" TablespaceName="PRIMARY" />
    </DbTable>
    <DbTable Name="IE_PROC_GRP_LG_RF" TablespaceName="PRIMARY">
      <Columns>
        <DbColumn Name="ITEM_ID" Precision="32" PkOrder="1" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="EVENT_TYPE" Precision="14" PkOrder="2" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="PERIOD" Precision="20" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="START_DATETIME" PkOrder="5" IsIdentity="False" IsNullable="False" LogicalDbType="Date" />
        <DbColumn Name="END_DATETIME" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="REF_ITEM_ID" Precision="50" PkOrder="3" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="PROC_GRP_RUN_ID" Precision="50" PkOrder="4" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="VAL1" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL2" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL3" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL4" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL5" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="DATE1" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE2" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE3" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="CHAR1" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR2" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR3" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR4" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR5" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_USER" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_DATE" DefaultValueType="Now" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="VERSION" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="DB_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ROW_ID" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="STATUS" Precision="10" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
          <DbColumn Name="UPDATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
          <DbColumn Name="CREATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
      </Columns>
      <Indexes>
        <DbIndex Name="IX_IE_PROC_GRP_LG_RF1" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_ID</string>
            <string>START_DATETIME</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_IE_PROC_GRP_LG_RF2" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_ID</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_IE_PROC_GRP_LG_RF3" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>EVENT_TYPE</string>
            <string>PROC_GRP_RUN_ID</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
            <string>REF_ITEM_ID</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_IE_PROC_GRP_LG_RF4" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_IE_PROC_GRP_LG_RF_RID" TablespaceName="PRIMARY" IsUnique="True">
          <ColumnNames>
            <string>ROW_ID</string>
          </ColumnNames>
        </DbIndex>
      </Indexes>
      <Triggers />
      <PrimaryKey Name="PK_IE_PROC_GRP_LG_RF" TablespaceName="PRIMARY" />
    </DbTable>
    <DbTable Name="IE_PROC_GRP_LOG" TablespaceName="PRIMARY">
      <Columns>
        <DbColumn Name="EVENT_GROUP_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ITEM_ID" Precision="32" PkOrder="1" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="EVENT_TYPE" Precision="14" PkOrder="2" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="PERIOD" Precision="20" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="START_DATETIME" PkOrder="5" IsIdentity="False" IsNullable="False" LogicalDbType="Date" />
        <DbColumn Name="END_DATETIME" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="PROC_GRP_RUN_ID" Precision="50" PkOrder="3" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="NAV_ITEM_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="DURATION" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL2" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL3" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL4" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL5" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="PROC_GRP_START" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="PROC_GRP_END" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE3" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE4" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE5" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="PROC_STATUS" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LOG_TEXT" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="DEBUG" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="PROC_GRP_NAME" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR5" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="DESCRIPTION" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="BLOB_ID" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR8" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR9" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR10" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR11" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR12" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR13" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR14" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR15" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_USER" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_DATE" DefaultValueType="Now" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="VERSION" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="DB_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ROW_ID" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="STATUS" Precision="10" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
          <DbColumn Name="UPDATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
          <DbColumn Name="CREATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
      </Columns>
      <Indexes>
        <DbIndex Name="IX_IE_PROC_GRP_LOG_RID" TablespaceName="PRIMARY" IsUnique="True">
          <ColumnNames>
            <string>ROW_ID</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_IE_PROC_GRP_LOG1" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
          </ColumnNames>
        </DbIndex>
      </Indexes>
      <Triggers />
      <PrimaryKey Name="PK_IE_PROC_GRP_LOG" TablespaceName="PRIMARY" />
    </DbTable>
    <DbTable Name="IE_PROC_LOG_HDR" TablespaceName="PRIMARY">
      <Columns>
        <DbColumn Name="EVENT_GROUP_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ITEM_ID" Precision="32" PkOrder="1" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="EVENT_TYPE" Precision="14" PkOrder="2" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="PERIOD" Precision="20" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="START_DATETIME" PkOrder="5" IsIdentity="False" IsNullable="False" LogicalDbType="Date" />
        <DbColumn Name="END_DATETIME" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="PROC_RUN_ID" Precision="50" PkOrder="3" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="NAV_ITEM_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="DURATION" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL2" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL3" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL4" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL5" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="PROCESS_START" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="PROCESS_END" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE3" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE4" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE5" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="BLOB_ID" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="PROC_GRP_RUN_ID" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="PROCESS_NAME" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="RESULT" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="PROC_STATUS" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="DEBUG" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR7" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR8" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR9" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR10" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR11" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR12" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR13" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR14" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR15" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_USER" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_DATE" DefaultValueType="Now" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="VERSION" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="DB_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ROW_ID" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="STATUS" Precision="10" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
          <DbColumn Name="UPDATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
          <DbColumn Name="CREATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
      </Columns>
      <Indexes>
        <DbIndex Name="IX_IE_PROC_LOG_HDR1" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_ID</string>
            <string>START_DATETIME</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_IE_PROC_LOG_HDR2" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>PROC_GRP_RUN_ID</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_IE_PROC_LOG_HDR3" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_IE_PROC_LOG_HDR_RID" TablespaceName="PRIMARY" IsUnique="True">
          <ColumnNames>
            <string>ROW_ID</string>
          </ColumnNames>
        </DbIndex>
      </Indexes>
      <Triggers />
      <PrimaryKey Name="PK_IE_PROC_LOG_HDR" TablespaceName="PRIMARY" />
    </DbTable>
    <DbTable Name="IE_PROC_LOG_REF" TablespaceName="PRIMARY">
      <Columns>
        <DbColumn Name="ITEM_ID" Precision="32" PkOrder="1" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="EVENT_TYPE" Precision="14" PkOrder="2" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="PERIOD" Precision="20" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="START_DATETIME" PkOrder="5" IsIdentity="False" IsNullable="False" LogicalDbType="Date" />
        <DbColumn Name="END_DATETIME" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="REF_ITEM_ID" Precision="50" PkOrder="3" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="PROC_RUN_ID" Precision="50" PkOrder="4" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="VAL1" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL2" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL3" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL4" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL5" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="DATE1" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE2" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE3" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE4" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE5" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="CHAR1" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR2" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR3" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR4" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR5" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR6" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR7" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR8" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR9" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR10" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR11" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR12" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR13" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR14" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR15" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_USER" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_DATE" DefaultValueType="Now" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="VERSION" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="DB_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ROW_ID" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="STATUS" Precision="10" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
          <DbColumn Name="UPDATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
          <DbColumn Name="CREATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
      </Columns>
      <Indexes>
        <DbIndex Name="IX_IE_PROC_LOG_REF1" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_ID</string>
            <string>START_DATETIME</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_IE_PROC_LOG_REF2" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_ID</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_IE_PROC_LOG_REF3" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>EVENT_TYPE</string>
            <string>PROC_RUN_ID</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
            <string>REF_ITEM_ID</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_IE_PROC_LOG_REF_RID" TablespaceName="PRIMARY" IsUnique="True">
          <ColumnNames>
            <string>ROW_ID</string>
          </ColumnNames>
        </DbIndex>
      </Indexes>
      <Triggers />
      <PrimaryKey Name="PK_IE_PROC_LOG_REF" TablespaceName="PRIMARY" />
    </DbTable>
    <DbTable Name="IE_PROCESS_LOG" TablespaceName="PRIMARY">
      <Columns>
        <DbColumn Name="EVENT_GROUP_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ITEM_ID" Precision="32" PkOrder="1" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="EVENT_TYPE" Precision="14" PkOrder="2" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="PERIOD" Precision="20" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="START_DATETIME" PkOrder="5" IsIdentity="False" IsNullable="False" LogicalDbType="Date" />
        <DbColumn Name="END_DATETIME" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="UNIQUE_ID" Precision="50" PkOrder="3" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="NAV_ITEM_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="DURATION" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="PROC_LOG_SEQ" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL3" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL4" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL5" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="PROCESS_START" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="PROC_LOG_TIME" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE3" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE4" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE5" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="PROC_STATUS" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LOG_TEXT" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="PROCESS_NAME" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR4" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="PROC_RUN_ID" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="DESCRIPTION" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="EXCEPTION" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR8" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR9" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR10" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR11" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR12" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR13" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR14" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR15" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_USER" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_DATE" DefaultValueType="Now" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="VERSION" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="DB_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ROW_ID" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="STATUS" Precision="10" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
          <DbColumn Name="UPDATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
          <DbColumn Name="CREATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
      </Columns>
      <Indexes>
        <DbIndex Name="IX_IE_PROCESS_LOG1" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>PROC_RUN_ID</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_IE_PROCESS_LOG2" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_IE_PROCESS_LOG3" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>NAV_ITEM_ID</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_IE_PROCESS_LOG_RID" TablespaceName="PRIMARY" IsUnique="True">
          <ColumnNames>
            <string>ROW_ID</string>
          </ColumnNames>
        </DbIndex>
      </Indexes>
      <Triggers />
      <PrimaryKey Name="PK_IE_PROCESS_LOG" TablespaceName="PRIMARY" />
    </DbTable>
    <DbTable Name="IE_REP_ITEM" TablespaceName="PRIMARY">
        <Columns>
          <DbColumn Name="ITEM_ID" Precision="32" PkOrder="1" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
          <DbColumn Name="EVENT_TYPE" Precision="14" PkOrder="2" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
          <DbColumn Name="PERIOD" Precision="20" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
          <DbColumn Name="START_DATETIME" PkOrder="3" IsIdentity="False" IsNullable="False" LogicalDbType="Date" />
          <DbColumn Name="END_DATETIME" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
          <DbColumn Name="REP_ITEM_CLASS"  PkOrder="4" Precision="14" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
          <DbColumn Name="REP_ITEM_ID" PkOrder="5" Precision="32" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
          <DbColumn Name="REP_ITEM_TYPE" Precision="14" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
          <DbColumn Name="LAST_UPDT_USER" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
          <DbColumn Name="LAST_UPDT_DATE" DefaultValueType="Now" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
          <DbColumn Name="VERSION" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
          <DbColumn Name="DB_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
          <DbColumn Name="ROW_ID" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
          <DbColumn Name="STATUS" Precision="10" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
          <DbColumn Name="UPDATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
          <DbColumn Name="CREATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        </Columns>
        <Indexes>
          <DbIndex Name="IX_IE_REP_ITEM_RID" TablespaceName="PRIMARY" IsUnique="True">
            <ColumnNames>
              <string>ROW_ID</string>
            </ColumnNames>
          </DbIndex>
        </Indexes>
        <Triggers />
        <PrimaryKey Name="PK_IE_REP_ITEM" TablespaceName="PRIMARY" />
      </DbTable>
      <DbTable Name="REPL_TEMP_CACHE" TablespaceName="PRIMARY">
      <Columns>
        <DbColumn Name="CACHE_ID" Precision="32" PkOrder="1" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="ROW_ID" Precision="32" PkOrder="2" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="TABLE_NAME" Precision="32" PkOrder="3" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
      </Columns>
      <Indexes />
      <Fks />
      <Triggers />
      <PrimaryKey Name="PK_REPL_TEMP_CACHE" TablespaceName="PRIMARY" />
    </DbTable>
    <DbTable Name="IE_REPL_LOG" TablespaceName="PRIMARY">
      <Columns>
        <DbColumn Name="EVENT_GROUP_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ITEM_ID" Precision="32" PkOrder="1" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="EVENT_TYPE" Precision="14" PkOrder="2" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="PERIOD" Precision="20" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="START_DATETIME" PkOrder="4" IsIdentity="False" IsNullable="False" LogicalDbType="Date" />
        <DbColumn Name="END_DATETIME" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="MSG_SEQ" Precision="28" Scale="12" PkOrder="3" IsIdentity="False" IsNullable="False" LogicalDbType="NumericData" />
        <DbColumn Name="MSG_TYPE" Precision="32" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="MESSAGE" Precision="2000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="MSG_TIME" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="LAST_UPDT_USER" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_DATE" DefaultValueType="Now" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="VERSION" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="DB_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ROW_ID" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="STATUS" Precision="10" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="SOURCE_DB" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="SOURCE_DATETIME" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="UPDATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="CREATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
      </Columns>
      <Indexes>
        <DbIndex Name="IX_IE_REPL_LOG1" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_IE_REPL_LOG_RID" TablespaceName="PRIMARY" IsUnique="True">
          <ColumnNames>
            <string>ROW_ID</string>
          </ColumnNames>
        </DbIndex>
      </Indexes>
      <Triggers />
      <PrimaryKey Name="PK_IE_REPL_LOG" TablespaceName="PRIMARY" />
    </DbTable>    
	  <DbTable Name="DIAG_SUB" TablespaceName="PRIMARY">
      <Columns>
        <DbColumn Name="ITEM_ID" Precision="32" PkOrder="1" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="EVENT_TYPE" Precision="14" PkOrder="2" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="START_DATETIME" PkOrder="4" IsIdentity="False" IsNullable="False" LogicalDbType="Date" />

        <DbColumn Name="DIAG_SUB_ID" Precision="32" PkOrder="3" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="NAME" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="IS_DEFAULT" Precision="5" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="PARENT_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ZOOM_FACTOR" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="OLD_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />

        <DbColumn Name="PERIOD" Precision="20" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="END_DATETIME" DefaultValueType="EndDatetime" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="LAST_UPDT_USER" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_DATE" DefaultValueType="Now" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="VERSION" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="DB_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ROW_ID" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="STATUS" Precision="10" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="UPDATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="CREATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
      </Columns>
      <Indexes>
        <!--<DbIndex Name="IX_DIAG_SUB" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
            <string>PERIOD</string>
            <string>START_DATETIME</string>
            <string>DIAG_SUB_ID</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_DIAG_SUB2" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_DIAG_SUB3" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>DIAG_SUB_ID</string>
            <string>PARENT_ID</string>
            <string>EVENT_TYPE</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_DIAG_SUB4" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>DIAG_SUB_ID</string>
            <string>IS_DEFAULT</string>
            <string>EVENT_TYPE</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_DIAG_SUB5" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
            <string>DIAG_SUB_ID</string>
          </ColumnNames>
        </DbIndex>-->
        <DbIndex Name="IX_DIAG_SUB6" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>DIAG_SUB_ID</string>
            <string>IS_DEFAULT</string>
            <string>ITEM_ID</string>
          </ColumnNames>
        </DbIndex>
        <!--<DbIndex Name="IX_DIAG_SUB7" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>DIAG_SUB_ID</string>
          </ColumnNames>
        </DbIndex>
         <DbIndex Name="IX_DIAG_SUB8" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>PARENT_ID</string>
            <string>EVENT_TYPE</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_DIAG_SUB9" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_ID</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_DIAG_SUB10" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_ID</string>
            <string>DIAG_SUB_ID</string>
          </ColumnNames>
        </DbIndex>-->
        <DbIndex Name="IX_DIAG_SUB_RID" TablespaceName="PRIMARY" IsUnique="True">
          <ColumnNames>
            <string>ROW_ID</string>
          </ColumnNames>
        </DbIndex>
      </Indexes>
      <Triggers />
      <PrimaryKey Name="PK_DIAG_SUB" TablespaceName="PRIMARY" />
    </DbTable>
    <DbTable Name="DIAG_NODE" TablespaceName="PRIMARY">
      <Columns>
        <DbColumn Name="ITEM_ID" Precision="32" PkOrder="1" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="EVENT_TYPE" Precision="14" PkOrder="2" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="START_DATETIME" PkOrder="4" IsIdentity="False" IsNullable="False" LogicalDbType="Date" />

        <DbColumn Name="DIAG_NODE_ID" Precision="32" PkOrder="3" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="DIAG_SUB_ID" Precision="32" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="CATEGORY" Precision="16" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="SUB_DIAGRAM_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="DIAG_TYPE_ID" Precision="64" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="MEMBER_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="R_ITEM_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="R_NETITEM_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="R_SUBDIAG_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />

        <DbColumn Name="PERIOD" Precision="20" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="END_DATETIME" DefaultValueType="EndDatetime" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="LAST_UPDT_USER" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_DATE" DefaultValueType="Now" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="VERSION" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="DB_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ROW_ID" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="STATUS" Precision="10" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="UPDATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="CREATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
      </Columns>
      <Indexes>
        <!--<DbIndex Name="IX_DIAG_NODE" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
            <string>PERIOD</string>
            <string>START_DATETIME</string>
            <string>DIAG_NODE_ID</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_DIAG_NODE2" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_DIAG_NODE3" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>DIAG_NODE_ID</string>
            <string>DIAG_SUB_ID</string>
            <string>EVENT_TYPE</string>
          </ColumnNames>
        </DbIndex>-->
        <DbIndex Name="IX_DIAG_NODE4" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
            <string>DIAG_NODE_ID</string>
          </ColumnNames>
        </DbIndex>
         <!--<DbIndex Name="IX_DIAG_NODE5" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>DIAG_SUB_ID</string>
          </ColumnNames>
        </DbIndex>-->
         <DbIndex Name="IX_DIAG_NODE6" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>DIAG_SUB_ID</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_DIAG_NODE_RID" TablespaceName="PRIMARY" IsUnique="True">
          <ColumnNames>
            <string>ROW_ID</string>
          </ColumnNames>
        </DbIndex>
      </Indexes>
      <Triggers />
      <PrimaryKey Name="PK_DIAG_NODE" TablespaceName="PRIMARY" />
    </DbTable>
    <DbTable Name="DIAG_ARROW" TablespaceName="PRIMARY">
      <Columns>
        <DbColumn Name="ITEM_ID" Precision="32" PkOrder="1" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="EVENT_TYPE" Precision="14" PkOrder="2" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="START_DATETIME" PkOrder="4" IsIdentity="False" IsNullable="False" LogicalDbType="Date" />

        <DbColumn Name="DIAG_ARROW_ID" Precision="32" PkOrder="3" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="DIAG_SUB_ID" Precision="32" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="CONN_ID" Precision="32" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="FROM_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="TO_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="DTYPE_ID" Precision="64" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="SUB_FROM_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="SUB_TO_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />

        <DbColumn Name="PERIOD" Precision="20" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="END_DATETIME" DefaultValueType="EndDatetime" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="LAST_UPDT_USER" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_DATE" DefaultValueType="Now" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="VERSION" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="DB_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ROW_ID" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="STATUS" Precision="10" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="UPDATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="CREATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
      </Columns>
      <Indexes>
        <!--<DbIndex Name="IX_DIAG_ARROW" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
            <string>PERIOD</string>
            <string>START_DATETIME</string>
            <string>DIAG_ARROW_ID</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_DIAG_ARROW2" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_DIAG_ARROW3" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>DIAG_ARROW_ID</string>
            <string>DIAG_SUB_ID</string>
            <string>FROM_ID</string>
            <string>TO_ID</string>
            <string>EVENT_TYPE</string>
          </ColumnNames>
        </DbIndex>-->
        <DbIndex Name="IX_DIAG_ARROW4" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
            <string>DIAG_SUB_ID</string>
            <string>DIAG_ARROW_ID</string>
          </ColumnNames>
        </DbIndex>
          <!--<DbIndex Name="IX_DIAG_ARROW5" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>DIAG_SUB_ID</string>
          </ColumnNames>
        </DbIndex>-->
         <DbIndex Name="IX_DIAG_ARROW6" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>  
            <string>DIAG_SUB_ID</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_DIAG_ARROW_RID" TablespaceName="PRIMARY" IsUnique="True">
          <ColumnNames>
            <string>ROW_ID</string>
          </ColumnNames>
        </DbIndex>
      </Indexes>
      <Triggers />
      <PrimaryKey Name="PK_DIAG_ARROW" TablespaceName="PRIMARY" />
    </DbTable>
    <DbTable Name="DIAG_TEMP_CACHE" TablespaceName="PRIMARY">
      <Columns>
        <DbColumn Name="CACHE_ID" Precision="32" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="OBJECT_ID" Precision="32" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="ITEM_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="START_DATETIME"  IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="END_DATETIME" DefaultValueType="EndDatetime" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="PARENT" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="OBJECT_TYPE" Precision="14" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="ID1" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ID2" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ID3" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ID4" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ID5" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ID6" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="OID1" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="OID2" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="OID3" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="OID4" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="OID5" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="OID6" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="INT1" Scale="0" DefaultValueType="Zero" IsIdentity="False" IsNullable="True" LogicalDbType="Integer" />
        <DbColumn Name="INT2" Scale="0" DefaultValueType="Zero" IsIdentity="False" IsNullable="True" LogicalDbType="Integer" />
        <DbColumn Name="INT3" Scale="0" DefaultValueType="Zero" IsIdentity="False" IsNullable="True" LogicalDbType="Integer" />
        <DbColumn Name="VAL1" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL2" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL3" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL4" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL5" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL6" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL7" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL8" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL9" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL10" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL11" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL12" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL13" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL14" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL15" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL16" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL17" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL18" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL19" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL20" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="DATE1" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE2" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE3" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE4" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="CODE1" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CODE2" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CODE3" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CODE4" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CODE5" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CODE6" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CODE7" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CODE8" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CODE9" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CODE10" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR1" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR2" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR3" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR4" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR5" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="STR1" Precision="64" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="STR2" Precision="64" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="LAST_UPDT_DATE" DefaultValueType="Now" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="UPDATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="CREATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
      </Columns>
      <Indexes>
        <DbIndex Name="IX_DIAG_TEMP_CACHE" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>CACHE_ID</string>
            <string>OBJECT_ID</string>
          </ColumnNames>
        </DbIndex>
      </Indexes>
    </DbTable>
    <DbTable Name="DIAG_OBJECT" TablespaceName="PRIMARY">
      <Columns>
        <DbColumn Name="ITEM_ID" Precision="32" PkOrder="1" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="EVENT_TYPE" Precision="14" PkOrder="2" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="START_DATETIME" PkOrder="4" IsIdentity="False" IsNullable="False" LogicalDbType="Date" />

        <DbColumn Name="DIAG_OBJECT_ID" Precision="32" PkOrder="3" IsIdentity="False" DefaultValueType="Guid" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="PARENT" Precision="32" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="OID1" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="OID2" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="OID3" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="OID4" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="OID5" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="OID6" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="INT1" Scale="0" DefaultValueType="Zero" IsIdentity="False" IsNullable="True" LogicalDbType="Integer" />
        <DbColumn Name="INT2" Scale="0" DefaultValueType="Zero" IsIdentity="False" IsNullable="True" LogicalDbType="Integer" />
        <DbColumn Name="INT3" Scale="0" DefaultValueType="Zero" IsIdentity="False" IsNullable="True" LogicalDbType="Integer" />
        <DbColumn Name="VAL1" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL2" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL3" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL4" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL5" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL6" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL7" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL8" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL9" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL10" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL11" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL12" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL13" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL14" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL15" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL16" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL17" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL18" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL19" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL20" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="DATE1" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE2" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE3" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="CODE1" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CODE2" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CODE3" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CODE4" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CODE5" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CODE6" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CODE7" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CODE8" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CODE9" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CODE10" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR1" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR2" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR3" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR4" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR5" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />

        <DbColumn Name="PERIOD" Precision="20" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="END_DATETIME" DefaultValueType="EndDatetime" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="LAST_UPDT_USER" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_DATE" DefaultValueType="Now" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="VERSION" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="DB_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ROW_ID" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="STATUS" Precision="10" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="UPDATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="CREATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
      </Columns>
      <Indexes>
        <!--<DbIndex Name="IX_DIAG_OBJECT" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
            <string>PERIOD</string>
            <string>START_DATETIME</string>
            <string>DIAG_OBJECT_ID</string>
          </ColumnNames>
        </DbIndex>-->
        <DbIndex Name="IX_DIAG_OBJECT2" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_DIAG_OBJECT3" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>DIAG_OBJECT_ID</string>
            <string>EVENT_TYPE</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_DIAG_OBJECT4" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
            <string>DIAG_OBJECT_ID</string>
          </ColumnNames>
        </DbIndex>
         <!--<DbIndex Name="IX_DIAG_OBJECT5" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>DIAG_OBJECT_ID</string>
          </ColumnNames>
        </DbIndex>
         <DbIndex Name="IX_DIAG_OBJECT6" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>DIAG_OBJECT_ID</string>
            <string>PARENT</string>
          </ColumnNames>
        </DbIndex>
         <DbIndex Name="IX_DIAG_OBJECT7" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>EVENT_TYPE</string>
          </ColumnNames>
        </DbIndex>-->
         <DbIndex Name="IX_DIAG_OBJECT8" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>PARENT</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
           </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_DIAG_OBJECT_RID" TablespaceName="PRIMARY" IsUnique="True">
          <ColumnNames>
            <string>ROW_ID</string>
          </ColumnNames>
        </DbIndex>
      </Indexes>
      <PrimaryKey Name="PK_DIAG_OBJECT" TablespaceName="PRIMARY" />
    </DbTable>
    <DbTable Name="DIAG_OBJECT_CACHE" TablespaceName="PRIMARY">
      <Columns>
        <!-- Standard transaction table columns-->
        <DbColumn Name="ITEM_ID" Precision="32"  IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="EVENT_TYPE" Precision="14" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="START_DATETIME" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="END_DATETIME" DefaultValueType="EndDatetime" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="PERIOD" Precision="20" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar"  />
        <DbColumn Name="LAST_UPDT_USER" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_DATE" DefaultValueType="Now" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="VERSION" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="STATUS" Precision="10" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />

        <!-- Temp cache columns-->
        <DbColumn Name="CACHE_ID" Precision="32" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="OBJECT_ID" Precision="32" IsIdentity="False" DefaultValueType="Guid" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="PARENT" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />

        <!-- Special temp cache columns-->
        <DbColumn Name="START_DATETIME1" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="START_DATETIME2" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="END_DATETIME1"   IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="END_DATETIME2"   IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="ID1" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ID2" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ID3" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="INTEGER1" Scale="0" IsIdentity="False" IsNullable="True" LogicalDbType="Integer" />
        <DbColumn Name="INTEGER2" Scale="0" IsIdentity="False" IsNullable="True" LogicalDbType="Integer" />

        <!-- DIAG_OBJECT data columns-->
        <DbColumn Name="OID1" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="OID2" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="OID3" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="OID4" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="OID5" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="OID6" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="INT1" Scale="0"      IsIdentity="False" IsNullable="True" LogicalDbType="Integer" />
        <DbColumn Name="INT2" Scale="0"      IsIdentity="False" IsNullable="True" LogicalDbType="Integer" />
        <DbColumn Name="INT3" Scale="0"      IsIdentity="False" IsNullable="True" LogicalDbType="Integer" />
        <DbColumn Name="VAL1" Precision="28"  Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL2" Precision="28"  Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL3" Precision="28"  Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL4" Precision="28"  Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL5" Precision="28"  Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL6" Precision="28"  Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL7" Precision="28"  Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL8" Precision="28"  Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL9" Precision="28"  Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL10" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL11" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL12" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL13" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL14" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL15" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL16" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL17" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL18" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL19" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL20" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="DATE1" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE2" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE3" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="CODE1" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CODE2" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CODE3" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CODE4" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CODE5" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CODE6" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CODE7" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CODE8" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CODE9" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CODE10" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR1" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR2" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR3" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR4" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR5" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="UPDATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="CREATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
      </Columns>
      <Indexes>
        <DbIndex Name="IX_DIAG_OBJECT_CACHE" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>CACHE_ID</string>
            <string>OBJECT_ID</string>
          </ColumnNames>
        </DbIndex>
      </Indexes>
    </DbTable>
    <DbTable Name="TAG_CACHE" TablespaceName="PRIMARY">
      <Columns>
        <DbColumn Name="ITEM_ID" Precision="32" PkOrder="1" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="EVENT_TYPE" Precision="14" PkOrder="2" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="TAG_ID" Precision="32" PkOrder="3" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="START_DATETIME" PkOrder="4" IsIdentity="False" IsNullable="False" LogicalDbType="Date" />
        <DbColumn Name="PARENT_TAG_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="NAME" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="DESCRIPTION" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="UOM" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="DATA_TYPE" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="DERIVE_EQUATION" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="EXCEPTION_DEV" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="EXCEPTION_DEV_TYPE" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="NODE_NAME" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="PROCESS_NAME" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="SOURCE_NAME" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="STEPPED" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="DATA_ACCESS_TYPE" Precision="200" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="NODE_DUMP" Precision="2000" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="NORMAL_MAXIMUM" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="NORMAL_MINIMUM" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="LIMIT_LOLO" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="LIMIT_HIHI" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="EVENT_NOTIFIER" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="NODE_CLASS" Precision="20" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="HISTORIZING" Precision="10" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="MINIMUM_SAMPLING_INTERVAL" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="PERIOD" Precision="20" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="END_DATETIME" DefaultValueType="EndDatetime" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="LAST_UPDT_USER" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_DATE" DefaultValueType="Now" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="VERSION" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="DB_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ROW_ID" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="STATUS" Precision="10" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="UPDATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="CREATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
      </Columns>
      <Indexes>
        <DbIndex Name="IX_TAG_CACHE" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
            <string>PERIOD</string>
            <string>START_DATETIME</string>
            <string>TAG_ID</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_TAG_CACHE2" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_TAG_CACHE3" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>PARENT_TAG_ID</string>
            <string>EVENT_TYPE</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_TAG_CACHE4" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
            <string>TAG_ID</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_TAG_CACHE_RID" TablespaceName="PRIMARY" IsUnique="True">
          <ColumnNames>
            <string>ROW_ID</string>
          </ColumnNames>
        </DbIndex>
      </Indexes>
      <PrimaryKey Name="PK_TAG_CACHE" TablespaceName="PRIMARY" />
    </DbTable>
    <DbTable Name="IE_TAG_MAP" TablespaceName="PRIMARY">
      <Columns>
        <DbColumn Name="EVENT_GROUP_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ITEM_ID" Precision="32" PkOrder="1" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="EVENT_TYPE" Precision="14" PkOrder="2" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="PERIOD" Precision="20" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="START_DATETIME" PkOrder="4" IsIdentity="False" IsNullable="False" LogicalDbType="Date" />
        <DbColumn Name="END_DATETIME" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="NAME" Precision="200" PkOrder="3" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="TARGET_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="TIME_OFFSET" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="INTERVAL" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="LIMIT_LO" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="LIMIT_HI" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="LIMIT_LO_LO" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="LIMIT_HI_HI" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL7" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL8" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL9" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="VAL10" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="DATE1" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="DATE2" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="TAG_ID" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="TRANS_TYPE" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="TRANS_PROPERTY" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="TAG_MAP_TYPE" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="INSTR_NAME" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="INSTR_TYPE" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="UOM" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="DATA_TYPE" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="DESCRIPTION" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="DEF_KEY_PROP1" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="DEF_KEY_VAL1" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="DEF_KEY_PROP2" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="DEF_KEY_VAL2" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="DEF_KEY_PROP3" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="DEF_KEY_VAL3" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LOAD" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR17" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR18" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR19" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR20" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="CHAR21" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_USER" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_DATE" DefaultValueType="Now" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="VERSION" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="DB_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ROW_ID" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="STATUS" Precision="10" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="REV_GRP_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="UPDATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="CREATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
      </Columns>
      <Indexes>
        <DbIndex Name="IX_IE_TAG_MAP" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>EVENT_GROUP_ID</string>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
            <string>PERIOD</string>
            <string>START_DATETIME</string>
            <string>NAME</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_IE_TAG_MAP2" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_IE_TAG_MAP3" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_IE_TAG_MAP4" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>TARGET_ID</string>
            <string>TRANS_TYPE</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_IE_TAG_MAP_TYPE" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>EVENT_TYPE</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_IE_TAG_MAP_RID" TablespaceName="PRIMARY" IsUnique="True">
          <ColumnNames>
            <string>ROW_ID</string>
          </ColumnNames>
        </DbIndex>
      </Indexes>
      <Fks>
        <DbFk Name="FK_IE_TAG_MAP_ITEM1" RefTableName="ITEM" UpdateRule="None" DeleteRule="None">
          <FkColumnNames>
            <string>TARGET_ID</string>
          </FkColumnNames>
          <RefColumnNames>
            <string>ITEM_ID</string>
          </RefColumnNames>
        </DbFk>
      </Fks>
      <Triggers />
      <PrimaryKey Name="PK_IE_TAG_MAP" TablespaceName="PRIMARY" />
    </DbTable>
    <DbTable Name="CONTEXT_HELP" TablespaceName="PRIMARY">
      <Columns>
        <DbColumn Name="ITEM_ID" Precision="32" PkOrder="1" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="EVENT_TYPE" Precision="14" PkOrder="2" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="START_DATETIME" PkOrder="4" IsIdentity="False" IsNullable="False" LogicalDbType="Date" />

        <DbColumn Name="HELP_ID" Precision="255" PkOrder="3" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="HELP_ID_TYPE" Precision="32" PkOrder="5" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="CULTURE" Precision="10"  PkOrder="6" DefaultValueType="Culture" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="LINK" Precision="1000" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />

        <DbColumn Name="EXP_INST_LAYER" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />

        <DbColumn Name="PERIOD" Precision="20" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="END_DATETIME" DefaultValueType="EndDatetime" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="LAST_UPDT_USER" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_DATE" DefaultValueType="Now" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="VERSION" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="DB_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ROW_ID" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="STATUS" Precision="10" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="UPDATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="CREATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
      </Columns>
      <Indexes>
        <DbIndex Name="IX_CONTEXT_HELP" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>HELP_ID</string>
            <string>HELP_ID_TYPE</string>
            <string>CULTURE</string>
            <string>ITEM_ID</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_CONTEXT_HELP_RID" TablespaceName="PRIMARY" IsUnique="True">
          <ColumnNames>
            <string>ROW_ID</string>
          </ColumnNames>
        </DbIndex>
      </Indexes>
      <Triggers />
      <PrimaryKey Name="PK_CONTEXT_HELP" TablespaceName="PRIMARY" />
    </DbTable>
    <DbTable Name="IE_SYS_USER_LOG" TablespaceName="PRIMARY">
      <Columns>
        <DbColumn Name="EVENT_GROUP_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ITEM_ID" Precision="32" PkOrder="2" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="EVENT_TYPE" Precision="14" PkOrder="1" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="PERIOD" Precision="20" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="START_DATETIME" PkOrder="3" IsIdentity="False" IsNullable="False" LogicalDbType="Date" />
        <DbColumn Name="END_DATETIME" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="ACTION_DATE" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="CONNECT_ACTION" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="APPLICATION" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_USER" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_DATE" DefaultValueType="Now" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="VERSION" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="DB_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ROW_ID" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="STATUS" Precision="10" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="UPDATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="CREATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="DATE1" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="VAL1" Precision="28" Scale="12" IsIdentity="False" IsNullable="True" LogicalDbType="NumericData" />
        <DbColumn Name="CHAR1" Precision="1000" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
      </Columns>
      <Indexes>
        <DbIndex Name="IX_IE_SYS_USER_LOG" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>EVENT_GROUP_ID</string>
            <string>ITEM_ID</string>
            <string>EVENT_TYPE</string>
            <string>PERIOD</string>
            <string>START_DATETIME</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_IE_SYS_USER_LOG_TYPE" TablespaceName="PRIMARY" IsUnique="False">
          <ColumnNames>
            <string>EVENT_TYPE</string>
            <string>START_DATETIME</string>
            <string>END_DATETIME</string>
          </ColumnNames>
        </DbIndex>
        <DbIndex Name="IX_IE_SYS_USER_LOG_RID" TablespaceName="PRIMARY" IsUnique="True">
          <ColumnNames>
            <string>ROW_ID</string>
          </ColumnNames>
        </DbIndex>
      </Indexes>
      <Fks />
      <Triggers />
      <PrimaryKey Name="PK_IE_SYS_USER_LOG" TablespaceName="PRIMARY" />
    </DbTable>
    <DbTable Name="ACCESS_CONTROL_ITEMS" TablespaceName="PRIMARY">
      <Columns>
        <DbColumn Name="USER_ID" Precision="32" PkOrder="1" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="ITEM_ID" Precision="32" PkOrder="2" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="START_DATETIME" PkOrder="3" IsIdentity="False" IsNullable="False" LogicalDbType="Date" />
        <DbColumn Name="END_DATETIME" DefaultValueType="EndDatetime" IsIdentity="False" IsNullable="False" LogicalDbType="Date" />
	    <DbColumn Name="LAST_UPDT_DATE" DefaultValueType="Now" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
      </Columns>
      <Indexes />
      <Triggers />
      <PrimaryKey Name="PK_ACCESS_CONTROL_ITEMS" TablespaceName="PRIMARY" />
    </DbTable>
    <DbTable Name="VALIDATION_LOG" TablespaceName="PRIMARY">
      <Columns>
        <DbColumn Name="EVENT_GROUP_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ITEM_ID" Precision="32" PkOrder="1" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="EVENT_TYPE" Precision="14" PkOrder="2" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="PERIOD" Precision="20" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="START_DATETIME" PkOrder="4" IsIdentity="False" IsNullable="False" LogicalDbType="Date" />
        <DbColumn Name="END_DATETIME" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="VALID_RULE_ID" Precision="50" PkOrder="3" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="VALID_ROW_ID" Precision="50" PkOrder="5" IsIdentity="False" IsNullable="False" LogicalDbType="Varchar" />
        <DbColumn Name="PROCESS_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="VALID_DATETIME" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="VALIDATOR" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="VALID_STATUS" Precision="14" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="MESSAGE" Precision="200" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="TYPE_NAME" Precision="14" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="PROPERTY_NAME" Precision="200" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="REF_ROW_ID" Precision="50" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="PROC_RUN_ID" Precision="200" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="ACK_COMMENT" Precision="200" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="ACK_LEVEL" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_USER" Precision="100" IsIdentity="False" IsNullable="True" LogicalDbType="Unicode" />
        <DbColumn Name="LAST_UPDT_DATE" DefaultValueType="Now" IsIdentity="False" IsNullable="True" LogicalDbType="Date" />
        <DbColumn Name="VERSION" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="DB_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="ROW_ID" Precision="32" DefaultValueType="Guid" IsIdentity="False" IsNullable="False" LogicalDbType="Char" />
        <DbColumn Name="STATUS" Precision="10" IsIdentity="False" IsNullable="True" LogicalDbType="Varchar" />
        <DbColumn Name="REV_GRP_ID" Precision="32" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="UPDATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
        <DbColumn Name="CREATE_SOURCE" Precision="1" DefaultValueType="SourceType" IsIdentity="False" IsNullable="True" LogicalDbType="Char" />
      </Columns>
      <Triggers />
      <PrimaryKey Name="PK_VALIDATION_LOG" TablespaceName="PRIMARY" />
    </DbTable>
  </Tables>
</DbInfo>"""

# %%
df = pd.read_xml(xml)

# %%
df
# Out:
#    DbFilegroup  DbTable
# 0          NaN      NaN
# 1          NaN      NaN
